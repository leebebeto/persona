# %%
import os
import re
import pickle

# %%
path = "../logs/rho100/DASTC__2020-07-01-01-18.log"

# %%
log_path = "../logs/rho1/"

# %%
log_files = os.listdir(log_path)
log_files = [i for i in log_files if i[-3:] == 'log']
log_files.sort()
log_file_path = log_files[-1]

# %%
log_files
# Out:
# ['DASTC__2020-06-29-15-28.log',
#  'DASTC__2020-06-29-15-29.log',
#  'DASTC__2020-06-29-15-35.log',
#  'DASTC__2020-06-29-15-36.log',
#  'DASTC__2020-06-29-15-39.log',
#  'DASTC__2020-06-29-15-40.log',
#  'DASTC__2020-06-30-08-07.log']

# %%
with open(path, 'r') as f:
    lines = f.readlines()

# %%
pickle_path = '../logs/imdb_lyrics_10.pickle'

# %%
with open(pickle_path , 'rb') as f:
    pk = pickle.load(f)

# %%
pk[0]
# Out:
# {'epoch': 1,
#  'iteration': 100,
#  'domain_acc': 0.7770061728395061,
#  'transfer_acc': 0.48148148148148145,
#  'blue': 0.04684147540877836}

# %% [markdown]
# ## Logic
# * Epoch line 찾기
# * Evaluate target domain 찾기
# * domain acc: [0-9].*[0-9]
# * transfer_acc: [0-9].*[0-9]
# * Blue score:
# * iteration 100 씩 더하다가 epoch 찾으면 초기화

# %%
import re
p = re.compile('epoch [0-9]*[0-9]')

# %%
m = p.search('epoch 3 dfdf')

# %%
print(m.span())
# Out:
# (0, 7)

# %%
def log2pickle(fpath, rho):
    
    with open(fpath, 'r') as f:
        lines = f.readlines()
    
    print("file path",fpath)
    pre_list = []
    p_epoch = re.compile('epoch [0-9]*[0-9]')
    p_do = re.compile('domain acc: [0-9].*[0-9]')
    p_tr = re.compile('transfer acc: [0-9].*[0-9]')
    p_bl = re.compile('Bleu score: [0-9].*[0-9]')
    p_save =re.compile('Saving style transfer model')
    temp_dict = {}
    epoch=0
    iteration = 100

    for idx, line in enumerate(lines):

        m = p_epoch.search(line)
        if m :
            epoch = int(m.group().split()[-1])
            iteration = 100

        m_do = p_do.search(line)

        if m_do :
            domain_acc = float(m_do.group().split()[-1])

        m_tr = p_tr.search(line)

        if m_tr:
            transfer_acc = float(m_tr.group().split()[-1])


        m_bl = p_bl.search(line)

        if m_bl:
            blue = float(m_bl.group().split()[-1])

        m_save = p_save.search(line)

        if m_save:
            # Append!
            pre_list.append({'epoch':epoch,'domain_acc':domain_acc,'transfer_acc':transfer_acc,'blue':blue, 'iteration':iteration})
            iteration += 100
            
    pickle_file_name = '../logs/' + 'rho_' + str(rho) + '.pickle'
    print("temp",pre_list[0])
    with open(pickle_file_name,'wb') as f:
        pickle.dump(pre_list, f, protocol=pickle.HIGHEST_PROTOCOL)
    return pre_list

# %%
pre_list = []
p_epoch = re.compile('epoch [0-9]*[0-9]')
p_do = re.compile('domain acc: [0-9].*[0-9]')
p_tr = re.compile('transfer acc: [0-9].*[0-9]')
p_bl = re.compile('Bleu score: [0-9].*[0-9]')
p_save =re.compile('Saving style transfer model')
temp_dict = {}
epoch=0
iteration = 100

for idx, line in enumerate(lines):
    
    m = p_epoch.search(line)
    if m :
        epoch = int(m.group().split()[-1])
        iteration = 100
    
    m_do = p_do.search(line)
    
    if m_do :
        domain_acc = float(m_do.group().split()[-1])
        
    m_tr = p_tr.search(line)

    if m_tr:
        transfer_acc = float(m_tr.group().split()[-1])
        
    
    m_bl = p_bl.search(line)

    if m_bl:
        blue = float(m_bl.group().split()[-1])
    
    m_save = p_save.search(line)
    
    if m_save:
        # Append!
        pre_list.append({'epoch':epoch,'domain_acc':domain_acc,'transfer_acc':transfer_acc,'blue':blue, 'iteration':iteration})
        iteration += 100

# %%
import shutil

# %%
log_path = "../logs/rho1/"
log_files = os.listdir(log_path)
log_files = [i for i in log_files if i[-3:] == 'log']
log_files.sort()
log_file_path = log_files[-1]
log_file_path
# Out:
# 'DASTC__2020-06-30-08-07.log'

# %%
log_files = os.listdir(log_path)
log_files = [i for i in log_files if i[-3:] == 'log']
log_files.sort()
log_file_path = os.path.join(log_path,log_files[-1])
log2pickle(log_file_path,rho)
# Out:
# file path ../logs/rho1/DASTC__2020-06-30-08-07.log
# temp {'epoch': 1, 'domain_acc': 1.0, 'transfer_acc': 0.4996, 'blue': 0.0366, 'iteration': 100}
# [{'epoch': 1,
#   'domain_acc': 1.0,
#   'transfer_acc': 0.4996,
#   'blue': 0.0366,
#   'iteration': 100},
#  {'epoch': 1,
#   'domain_acc': 1.0,
#   'transfer_acc': 0.4767,
#   'blue': 0.0229,
#   'iteration': 200},
#  {'epoch': 1,
#   'domain_acc': 1.0,
#   'transfer_acc': 0.4659,
#   'blue': 0.013,
#   'iteration': 300},
#  {'epoch': 1,
#   'domain_acc': 1.0,
#   'transfer_acc': 0.4993,
#   'blue': 0.0147,
#   'iteration': 400},
#  {'epoch': 1,
#   'domain_acc': 0.9986,
#   'transfer_acc': 0.5022,
#   'blue': 0.0291,
#   'iteration': 500},
#  {'epoch': 1,
#   'domain_acc': 0.9994,
#   'transfer_acc': 0.5149,
#   'blue': 0.0341,
#   'iteration': 600},
#  {'epoch': 1,
#   'domain_acc': 0.9977,
#   'transfer_acc': 0.521,
#   'blue': 0.0439,
#   'iteration': 700},
#  {'epoch': 1,
#   'domain_acc': 0.9986,
#   'transfer_acc': 0.5262,
#   'blue': 0.0517,
#   'iteration': 800},
#  {'epoch': 1,
#   'domain_acc': 0.9998,
#   'transfer_acc': 0.5452,
#   'blue': 0.0641,
#   'iteration': 900},
#  {'epoch': 1,
#   'domain_acc': 0.9989,
#   'transfer_acc': 0.5562,
#   'blue': 0.0736,
#   'iteration': 1000},
#  {'epoch': 1,
#   'domain_acc': 0.9998,
#   'transfer_acc': 0.5674,
#   'blue': 0.087,
#   'iteration': 1100},
#  {'epoch': 1,
#   'domain_acc': 0.9991,
#   'transfer_acc': 0.5792,
#   'blue': 0.1027,
#   'iteration': 1200},
#  {'epoch': 1,
#   'domain_acc': 0.9984,
#   'transfer_acc': 0.5798,
#   'blue': 0.1178,
#   'iteration': 1300},
#  {'epoch': 1,
#   'domain_acc': 0.9994,
#   'transfer_acc': 0.5916,
#   'blue': 0.1384,
#   'iteration': 1400},
#  {'epoch': 1,
#   'domain_acc': 0.9983,
#   'transfer_acc': 0.5866,
#   'blue': 0.1416,
#   'iteration': 1500},
#  {'epoch': 1,
#   'domain_acc': 0.9989,
#   'transfer_acc': 0.606,
#   'blue': 0.1739,
#   'iteration': 1600},
#  {'epoch': 1,
#   'domain_acc': 0.998,
#   'transfer_acc': 0.5963,
#   'blue': 0.1895,
#   'iteration': 1700},
#  {'epoch': 1,
#   'domain_acc': 0.9983,
#   'transfer_acc': 0.6066,
#   'blue': 0.2,
#   'iteration': 1800},
#  {'epoch': 1,
#   'domain_acc': 0.9979,
#   'transfer_acc': 0.6087,
#   'blue': 0.2247,
#   'iteration': 1900},
#  {'epoch': 1,
#   'domain_acc': 0.9986,
#   'transfer_acc': 0.6097,
#   'blue': 0.2323,
#   'iteration': 2000},
#  {'epoch': 1,
#   'domain_acc': 0.9988,
#   'transfer_acc': 0.619,
#   'blue': 0.2556,
#   'iteration': 2100},
#  {'epoch': 1,
#   'domain_acc': 0.9986,
#   'transfer_acc': 0.6273,
#   'blue': 0.2552,
#   'iteration': 2200},
#  {'epoch': 1,
#   'domain_acc': 0.9991,
#   'transfer_acc': 0.6222,
#   'blue': 0.2927,
#   'iteration': 2300},
#  {'epoch': 1,
#   'domain_acc': 0.9969,
#   'transfer_acc': 0.592,
#   'blue': 0.2301,
#   'iteration': 2400},
#  {'epoch': 1,
#   'domain_acc': 0.9978,
#   'transfer_acc': 0.5993,
#   'blue': 0.3089,
#   'iteration': 2500},
#  {'epoch': 1,
#   'domain_acc': 0.9983,
#   'transfer_acc': 0.5954,
#   'blue': 0.3345,
#   'iteration': 2600},
#  {'epoch': 1,
#   'domain_acc': 0.999,
#   'transfer_acc': 0.598,
#   'blue': 0.3465,
#   'iteration': 2700},
#  {'epoch': 1,
#   'domain_acc': 0.9977,
#   'transfer_acc': 0.5979,
#   'blue': 0.3636,
#   'iteration': 2800},
#  {'epoch': 2,
#   'domain_acc': 0.998,
#   'transfer_acc': 0.5906,
#   'blue': 0.3737,
#   'iteration': 100},
#  {'epoch': 2,
#   'domain_acc': 0.9983,
#   'transfer_acc': 0.5764,
#   'blue': 0.3897,
#   'iteration': 200},
#  {'epoch': 2,
#   'domain_acc': 0.9984,
#   'transfer_acc': 0.5809,
#   'blue': 0.3989,
#   'iteration': 300},
#  {'epoch': 2,
#   'domain_acc': 0.9972,
#   'transfer_acc': 0.569,
#   'blue': 0.4132,
#   'iteration': 400},
#  {'epoch': 2,
#   'domain_acc': 0.998,
#   'transfer_acc': 0.5781,
#   'blue': 0.4291,
#   'iteration': 500},
#  {'epoch': 2,
#   'domain_acc': 0.9978,
#   'transfer_acc': 0.5748,
#   'blue': 0.44,
#   'iteration': 600},
#  {'epoch': 2,
#   'domain_acc': 0.9979,
#   'transfer_acc': 0.5711,
#   'blue': 0.4445,
#   'iteration': 700},
#  {'epoch': 2,
#   'domain_acc': 0.9975,
#   'transfer_acc': 0.5658,
#   'blue': 0.4553,
#   'iteration': 800},
#  {'epoch': 2,
#   'domain_acc': 0.998,
#   'transfer_acc': 0.5562,
#   'blue': 0.4729,
#   'iteration': 900},
#  {'epoch': 2,
#   'domain_acc': 0.9978,
#   'transfer_acc': 0.5634,
#   'blue': 0.4825,
#   'iteration': 1000},
#  {'epoch': 2,
#   'domain_acc': 0.9984,
#   'transfer_acc': 0.5478,
#   'blue': 0.4906,
#   'iteration': 1100},
#  {'epoch': 2,
#   'domain_acc': 0.9985,
#   'transfer_acc': 0.5573,
#   'blue': 0.4995,
#   'iteration': 1200},
#  {'epoch': 2,
#   'domain_acc': 0.9978,
#   'transfer_acc': 0.5448,
#   'blue': 0.51,
#   'iteration': 1300},
#  {'epoch': 2,
#   'domain_acc': 0.998,
#   'transfer_acc': 0.5497,
#   'blue': 0.5249,
#   'iteration': 1400},
#  {'epoch': 2,
#   'domain_acc': 0.9978,
#   'transfer_acc': 0.5384,
#   'blue': 0.5278,
#   'iteration': 1500},
#  {'epoch': 2,
#   'domain_acc': 0.998,
#   'transfer_acc': 0.5474,
#   'blue': 0.5347,
#   'iteration': 1600},
#  {'epoch': 2,
#   'domain_acc': 0.9985,
#   'transfer_acc': 0.5293,
#   'blue': 0.5439,
#   'iteration': 1700},
#  {'epoch': 2,
#   'domain_acc': 0.9979,
#   'transfer_acc': 0.5303,
#   'blue': 0.5533,
#   'iteration': 1800},
#  {'epoch': 2,
#   'domain_acc': 0.9986,
#   'transfer_acc': 0.5222,
#   'blue': 0.5634,
#   'iteration': 1900},
#  {'epoch': 2,
#   'domain_acc': 0.998,
#   'transfer_acc': 0.5239,
#   'blue': 0.5701,
#   'iteration': 2000},
#  {'epoch': 2,
#   'domain_acc': 0.9986,
#   'transfer_acc': 0.5215,
#   'blue': 0.5718,
#   'iteration': 2100},
#  {'epoch': 2,
#   'domain_acc': 0.9974,
#   'transfer_acc': 0.5152,
#   'blue': 0.5852,
#   'iteration': 2200},
#  {'epoch': 2,
#   'domain_acc': 0.9988,
#   'transfer_acc': 0.5133,
#   'blue': 0.5895,
#   'iteration': 2300},
#  {'epoch': 2,
#   'domain_acc': 0.998,
#   'transfer_acc': 0.5179,
#   'blue': 0.5591,
#   'iteration': 2400},
#  {'epoch': 2,
#   'domain_acc': 0.9982,
#   'transfer_acc': 0.5099,
#   'blue': 0.6037,
#   'iteration': 2500},
#  {'epoch': 2,
#   'domain_acc': 0.9989,
#   'transfer_acc': 0.5066,
#   'blue': 0.6092,
#   'iteration': 2600},
#  {'epoch': 2,
#   'domain_acc': 0.9983,
#   'transfer_acc': 0.5031,
#   'blue': 0.616,
#   'iteration': 2700},
#  {'epoch': 2,
#   'domain_acc': 0.998,
#   'transfer_acc': 0.5048,
#   'blue': 0.6208,
#   'iteration': 2800},
#  {'epoch': 3,
#   'domain_acc': 0.9991,
#   'transfer_acc': 0.5009,
#   'blue': 0.6261,
#   'iteration': 100},
#  {'epoch': 3,
#   'domain_acc': 0.9984,
#   'transfer_acc': 0.4984,
#   'blue': 0.591,
#   'iteration': 200},
#  {'epoch': 3,
#   'domain_acc': 0.9982,
#   'transfer_acc': 0.4984,
#   'blue': 0.6369,
#   'iteration': 300},
#  {'epoch': 3,
#   'domain_acc': 0.9978,
#   'transfer_acc': 0.4936,
#   'blue': 0.6398,
#   'iteration': 400},
#  {'epoch': 3,
#   'domain_acc': 0.9983,
#   'transfer_acc': 0.487,
#   'blue': 0.6391,
#   'iteration': 500},
#  {'epoch': 3,
#   'domain_acc': 0.9968,
#   'transfer_acc': 0.4886,
#   'blue': 0.6456,
#   'iteration': 600},
#  {'epoch': 3,
#   'domain_acc': 0.9977,
#   'transfer_acc': 0.4915,
#   'blue': 0.6452,
#   'iteration': 700},
#  {'epoch': 3,
#   'domain_acc': 0.9983,
#   'transfer_acc': 0.4829,
#   'blue': 0.6533,
#   'iteration': 800},
#  {'epoch': 3,
#   'domain_acc': 0.9974,
#   'transfer_acc': 0.4831,
#   'blue': 0.6586,
#   'iteration': 900},
#  {'epoch': 3,
#   'domain_acc': 0.9979,
#   'transfer_acc': 0.4736,
#   'blue': 0.6698,
#   'iteration': 1000},
#  {'epoch': 3,
#   'domain_acc': 0.9979,
#   'transfer_acc': 0.4718,
#   'blue': 0.6722,
#   'iteration': 1100},
#  {'epoch': 3,
#   'domain_acc': 0.998,
#   'transfer_acc': 0.4724,
#   'blue': 0.674,
#   'iteration': 1200},
#  {'epoch': 3,
#   'domain_acc': 0.9973,
#   'transfer_acc': 0.4747,
#   'blue': 0.6778,
#   'iteration': 1300},
#  {'epoch': 3,
#   'domain_acc': 0.9975,
#   'transfer_acc': 0.474,
#   'blue': 0.684,
#   'iteration': 1400},
#  {'epoch': 3,
#   'domain_acc': 0.998,
#   'transfer_acc': 0.4697,
#   'blue': 0.6839,
#   'iteration': 1500},
#  {'epoch': 3,
#   'domain_acc': 0.9973,
#   'transfer_acc': 0.4657,
#   'blue': 0.6883,
#   'iteration': 1600},
#  {'epoch': 3,
#   'domain_acc': 0.9979,
#   'transfer_acc': 0.4617,
#   'blue': 0.6923,
#   'iteration': 1700},
#  {'epoch': 3,
#   'domain_acc': 0.9975,
#   'transfer_acc': 0.4627,
#   'blue': 0.6893,
#   'iteration': 1800},
#  {'epoch': 3,
#   'domain_acc': 0.9964,
#   'transfer_acc': 0.4641,
#   'blue': 0.6872,
#   'iteration': 1900},
#  {'epoch': 3,
#   'domain_acc': 0.9977,
#   'transfer_acc': 0.4517,
#   'blue': 0.6985,
#   'iteration': 2000},
#  {'epoch': 3,
#   'domain_acc': 0.9971,
#   'transfer_acc': 0.4546,
#   'blue': 0.7036,
#   'iteration': 2100},
#  {'epoch': 3,
#   'domain_acc': 0.9969,
#   'transfer_acc': 0.4548,
#   'blue': 0.7058,
#   'iteration': 2200},
#  {'epoch': 3,
#   'domain_acc': 0.9959,
#   'transfer_acc': 0.4541,
#   'blue': 0.7104,
#   'iteration': 2300},
#  {'epoch': 3,
#   'domain_acc': 0.9959,
#   'transfer_acc': 0.4503,
#   'blue': 0.7073,
#   'iteration': 2400},
#  {'epoch': 3,
#   'domain_acc': 0.9973,
#   'transfer_acc': 0.4444,
#   'blue': 0.7151,
#   'iteration': 2500},
#  {'epoch': 3,
#   'domain_acc': 0.9969,
#   'transfer_acc': 0.4403,
#   'blue': 0.7174,
#   'iteration': 2600},
#  {'epoch': 3,
#   'domain_acc': 0.9964,
#   'transfer_acc': 0.4522,
#   'blue': 0.7179,
#   'iteration': 2700},
#  {'epoch': 3,
#   'domain_acc': 0.9963,
#   'transfer_acc': 0.4425,
#   'blue': 0.7214,
#   'iteration': 2800},
#  {'epoch': 3,
#   'domain_acc': 0.9968,
#   'transfer_acc': 0.4416,
#   'blue': 0.7227,
#   'iteration': 2900},
#  {'epoch': 4,
#   'domain_acc': 0.9964,
#   'transfer_acc': 0.4368,
#   'blue': 0.7276,
#   'iteration': 100},
#  {'epoch': 4,
#   'domain_acc': 0.9959,
#   'transfer_acc': 0.4353,
#   'blue': 0.7325,
#   'iteration': 200},
#  {'epoch': 4,
#   'domain_acc': 0.9963,
#   'transfer_acc': 0.4392,
#   'blue': 0.7301,
#   'iteration': 300},
#  {'epoch': 4,
#   'domain_acc': 0.9962,
#   'transfer_acc': 0.4325,
#   'blue': 0.7355,
#   'iteration': 400},
#  {'epoch': 4,
#   'domain_acc': 0.9966,
#   'transfer_acc': 0.44,
#   'blue': 0.7281,
#   'iteration': 500},
#  {'epoch': 4,
#   'domain_acc': 0.9968,
#   'transfer_acc': 0.4323,
#   'blue': 0.7382,
#   'iteration': 600},
#  {'epoch': 4,
#   'domain_acc': 0.9964,
#   'transfer_acc': 0.4391,
#   'blue': 0.742,
#   'iteration': 700},
#  {'epoch': 4,
#   'domain_acc': 0.9955,
#   'transfer_acc': 0.432,
#   'blue': 0.7438,
#   'iteration': 800},
#  {'epoch': 4,
#   'domain_acc': 0.9961,
#   'transfer_acc': 0.4331,
#   'blue': 0.7411,
#   'iteration': 900},
#  {'epoch': 4,
#   'domain_acc': 0.9962,
#   'transfer_acc': 0.4277,
#   'blue': 0.7489,
#   'iteration': 1000},
#  {'epoch': 4,
#   'domain_acc': 0.9951,
#   'transfer_acc': 0.421,
#   'blue': 0.7534,
#   'iteration': 1100},
#  {'epoch': 4,
#   'domain_acc': 0.9963,
#   'transfer_acc': 0.4256,
#   'blue': 0.7499,
#   'iteration': 1200},
#  {'epoch': 4,
#   'domain_acc': 0.9957,
#   'transfer_acc': 0.4252,
#   'blue': 0.7513,
#   'iteration': 1300},
#  {'epoch': 4,
#   'domain_acc': 0.9944,
#   'transfer_acc': 0.4182,
#   'blue': 0.7547,
#   'iteration': 1400},
#  {'epoch': 4,
#   'domain_acc': 0.9957,
#   'transfer_acc': 0.423,
#   'blue': 0.746,
#   'iteration': 1500},
#  {'epoch': 4,
#   'domain_acc': 0.9945,
#   'transfer_acc': 0.4231,
#   'blue': 0.7587,
#   'iteration': 1600},
#  {'epoch': 4,
#   'domain_acc': 0.9953,
#   'transfer_acc': 0.4154,
#   'blue': 0.7616,
#   'iteration': 1700},
#  {'epoch': 4,
#   'domain_acc': 0.9952,
#   'transfer_acc': 0.4214,
#   'blue': 0.7624,
#   'iteration': 1800},
#  {'epoch': 4,
#   'domain_acc': 0.9953,
#   'transfer_acc': 0.4142,
#   'blue': 0.7669,
#   'iteration': 1900},
#  {'epoch': 4,
#   'domain_acc': 0.9969,
#   'transfer_acc': 0.4515,
#   'blue': 0.6239,
#   'iteration': 2000},
#  {'epoch': 4,
#   'domain_acc': 0.9948,
#   'transfer_acc': 0.4116,
#   'blue': 0.7695,
#   'iteration': 2100},
#  {'epoch': 4,
#   'domain_acc': 0.9953,
#   'transfer_acc': 0.4186,
#   'blue': 0.7688,
#   'iteration': 2200},
#  {'epoch': 4,
#   'domain_acc': 0.9951,
#   'transfer_acc': 0.4143,
#   'blue': 0.7716,
#   'iteration': 2300},
#  {'epoch': 4,
#   'domain_acc': 0.9951,
#   'transfer_acc': 0.4099,
#   'blue': 0.7754,
#   'iteration': 2400},
#  {'epoch': 4,
#   'domain_acc': 0.9951,
#   'transfer_acc': 0.4137,
#   'blue': 0.7743,
#   'iteration': 2500},
#  {'epoch': 4,
#   'domain_acc': 0.9961,
#   'transfer_acc': 0.4085,
#   'blue': 0.7761,
#   'iteration': 2600},
#  {'epoch': 4,
#   'domain_acc': 0.9939,
#   'transfer_acc': 0.409,
#   'blue': 0.7756,
#   'iteration': 2700},
#  {'epoch': 4,
#   'domain_acc': 0.9953,
#   'transfer_acc': 0.3966,
#   'blue': 0.7805,
#   'iteration': 2800},
#  {'epoch': 5,
#   'domain_acc': 0.995,
#   'transfer_acc': 0.3993,
#   'blue': 0.7805,
#   'iteration': 100},
#  {'epoch': 5,
#   'domain_acc': 0.9947,
#   'transfer_acc': 0.4053,
#   'blue': 0.776,
#   'iteration': 200},
#  {'epoch': 5,
#   'domain_acc': 0.9947,
#   'transfer_acc': 0.4051,
#   'blue': 0.782,
#   'iteration': 300},
#  {'epoch': 5,
#   'domain_acc': 0.9946,
#   'transfer_acc': 0.4057,
#   'blue': 0.7827,
#   'iteration': 400},
#  {'epoch': 5,
#   'domain_acc': 0.9929,
#   'transfer_acc': 0.4015,
#   'blue': 0.786,
#   'iteration': 500},
#  {'epoch': 5,
#   'domain_acc': 0.9934,
#   'transfer_acc': 0.403,
#   'blue': 0.7875,
#   'iteration': 600},
#  {'epoch': 5,
#   'domain_acc': 0.9936,
#   'transfer_acc': 0.4019,
#   'blue': 0.7872,
#   'iteration': 700},
#  {'epoch': 5,
#   'domain_acc': 0.9937,
#   'transfer_acc': 0.3935,
#   'blue': 0.7911,
#   'iteration': 800},
#  {'epoch': 5,
#   'domain_acc': 0.9935,
#   'transfer_acc': 0.4015,
#   'blue': 0.7906,
#   'iteration': 900},
#  {'epoch': 5,
#   'domain_acc': 0.995,
#   'transfer_acc': 0.3992,
#   'blue': 0.7904,
#   'iteration': 1000},
#  {'epoch': 5,
#   'domain_acc': 0.994,
#   'transfer_acc': 0.4036,
#   'blue': 0.7778,
#   'iteration': 1100},
#  {'epoch': 5,
#   'domain_acc': 0.9937,
#   'transfer_acc': 0.3964,
#   'blue': 0.7923,
#   'iteration': 1200},
#  {'epoch': 5,
#   'domain_acc': 0.9936,
#   'transfer_acc': 0.3885,
#   'blue': 0.798,
#   'iteration': 1300},
#  {'epoch': 5,
#   'domain_acc': 0.994,
#   'transfer_acc': 0.3921,
#   'blue': 0.7982,
#   'iteration': 1400},
#  {'epoch': 5,
#   'domain_acc': 0.9934,
#   'transfer_acc': 0.3948,
#   'blue': 0.7964,
#   'iteration': 1500},
#  {'epoch': 5,
#   'domain_acc': 0.994,
#   'transfer_acc': 0.397,
#   'blue': 0.7977,
#   'iteration': 1600},
#  {'epoch': 5,
#   'domain_acc': 0.9937,
#   'transfer_acc': 0.3876,
#   'blue': 0.7985,
#   'iteration': 1700},
#  {'epoch': 5,
#   'domain_acc': 0.9934,
#   'transfer_acc': 0.3895,
#   'blue': 0.7997,
#   'iteration': 1800},
#  {'epoch': 5,
#   'domain_acc': 0.9936,
#   'transfer_acc': 0.3872,
#   'blue': 0.7985,
#   'iteration': 1900},
#  {'epoch': 5,
#   'domain_acc': 0.9944,
#   'transfer_acc': 0.3983,
#   'blue': 0.7684,
#   'iteration': 2000},
#  {'epoch': 5,
#   'domain_acc': 0.9939,
#   'transfer_acc': 0.3889,
#   'blue': 0.8014,
#   'iteration': 2100},
#  {'epoch': 5,
#   'domain_acc': 0.9946,
#   'transfer_acc': 0.388,
#   'blue': 0.8057,
#   'iteration': 2200},
#  {'epoch': 5,
#   'domain_acc': 0.9935,
#   'transfer_acc': 0.3885,
#   'blue': 0.8061,
#   'iteration': 2300},
#  {'epoch': 5,
#   'domain_acc': 0.9935,
#   'transfer_acc': 0.3868,
#   'blue': 0.8093,
#   'iteration': 2400},
#  {'epoch': 5,
#   'domain_acc': 0.9948,
#   'transfer_acc': 0.3827,
#   'blue': 0.8071,
#   'iteration': 2500},
#  {'epoch': 5,
#   'domain_acc': 0.9941,
#   'transfer_acc': 0.3803,
#   'blue': 0.8095,
#   'iteration': 2600},
#  {'epoch': 5,
#   'domain_acc': 0.9947,
#   'transfer_acc': 0.381,
#   'blue': 0.8058,
#   'iteration': 2700},
#  {'epoch': 5,
#   'domain_acc': 0.9926,
#   'transfer_acc': 0.38,
#   'blue': 0.8132,
#   'iteration': 2800},
#  {'epoch': 6,
#   'domain_acc': 0.9929,
#   'transfer_acc': 0.3806,
#   'blue': 0.8119,
#   'iteration': 100},
#  {'epoch': 6,
#   'domain_acc': 0.9934,
#   'transfer_acc': 0.3805,
#   'blue': 0.8112,
#   'iteration': 200},
#  {'epoch': 6,
#   'domain_acc': 0.992,
#   'transfer_acc': 0.3818,
#   'blue': 0.8151,
#   'iteration': 300},
#  {'epoch': 6,
#   'domain_acc': 0.9931,
#   'transfer_acc': 0.3831,
#   'blue': 0.8158,
#   'iteration': 400},
#  {'epoch': 6,
#   'domain_acc': 0.9918,
#   'transfer_acc': 0.3738,
#   'blue': 0.8171,
#   'iteration': 500},
#  {'epoch': 6,
#   'domain_acc': 0.9918,
#   'transfer_acc': 0.3767,
#   'blue': 0.8182,
#   'iteration': 600},
#  {'epoch': 6,
#   'domain_acc': 0.9918,
#   'transfer_acc': 0.384,
#   'blue': 0.8176,
#   'iteration': 700},
#  {'epoch': 6,
#   'domain_acc': 0.9926,
#   'transfer_acc': 0.3759,
#   'blue': 0.8144,
#   'iteration': 800},
#  {'epoch': 6,
#   'domain_acc': 0.9919,
#   'transfer_acc': 0.3777,
#   'blue': 0.8161,
#   'iteration': 900},
#  {'epoch': 6,
#   'domain_acc': 0.9929,
#   'transfer_acc': 0.3765,
#   'blue': 0.8192,
#   'iteration': 1000},
#  {'epoch': 6,
#   'domain_acc': 0.9919,
#   'transfer_acc': 0.3729,
#   'blue': 0.8202,
#   'iteration': 1100},
#  {'epoch': 6,
#   'domain_acc': 0.9919,
#   'transfer_acc': 0.3719,
#   'blue': 0.8215,
#   'iteration': 1200},
#  {'epoch': 6,
#   'domain_acc': 0.9925,
#   'transfer_acc': 0.3734,
#   'blue': 0.8231,
#   'iteration': 1300},
#  {'epoch': 6,
#   'domain_acc': 0.9924,
#   'transfer_acc': 0.3754,
#   'blue': 0.8207,
#   'iteration': 1400},
#  {'epoch': 6,
#   'domain_acc': 0.9928,
#   'transfer_acc': 0.3735,
#   'blue': 0.8209,
#   'iteration': 1500},
#  {'epoch': 6,
#   'domain_acc': 0.9925,
#   'transfer_acc': 0.3735,
#   'blue': 0.825,
#   'iteration': 1600},
#  {'epoch': 6,
#   'domain_acc': 0.991,
#   'transfer_acc': 0.3755,
#   'blue': 0.825,
#   'iteration': 1700},
#  {'epoch': 6,
#   'domain_acc': 0.9926,
#   'transfer_acc': 0.37,
#   'blue': 0.8249,
#   'iteration': 1800},
#  {'epoch': 6,
#   'domain_acc': 0.993,
#   'transfer_acc': 0.3741,
#   'blue': 0.8169,
#   'iteration': 1900},
#  {'epoch': 6,
#   'domain_acc': 0.9923,
#   'transfer_acc': 0.3759,
#   'blue': 0.8248,
#   'iteration': 2000},
#  {'epoch': 6,
#   'domain_acc': 0.9899,
#   'transfer_acc': 0.3697,
#   'blue': 0.8272,
#   'iteration': 2100},
#  {'epoch': 6,
#   'domain_acc': 0.9908,
#   'transfer_acc': 0.367,
#   'blue': 0.8289,
#   'iteration': 2200},
#  {'epoch': 6,
#   'domain_acc': 0.9899,
#   'transfer_acc': 0.3727,
#   'blue': 0.8286,
#   'iteration': 2300},
#  {'epoch': 6,
#   'domain_acc': 0.991,
#   'transfer_acc': 0.3687,
#   'blue': 0.8285,
#   'iteration': 2400},
#  {'epoch': 6,
#   'domain_acc': 0.9913,
#   'transfer_acc': 0.3708,
#   'blue': 0.8328,
#   'iteration': 2500},
#  {'epoch': 6,
#   'domain_acc': 0.9923,
#   'transfer_acc': 0.3702,
#   'blue': 0.8285,
#   'iteration': 2600},
#  {'epoch': 6,
#   'domain_acc': 0.9918,
#   'transfer_acc': 0.3658,
#   'blue': 0.8318,
#   'iteration': 2700},
#  {'epoch': 6,
#   'domain_acc': 0.9913,
#   'transfer_acc': 0.367,
#   'blue': 0.8334,
#   'iteration': 2800},
#  {'epoch': 6,
#   'domain_acc': 0.9913,
#   'transfer_acc': 0.3682,
#   'blue': 0.8323,
#   'iteration': 2900},
#  {'epoch': 7,
#   'domain_acc': 0.991,
#   'transfer_acc': 0.3684,
#   'blue': 0.8337,
#   'iteration': 100},
#  {'epoch': 7,
#   'domain_acc': 0.9912,
#   'transfer_acc': 0.3616,
#   'blue': 0.8331,
#   'iteration': 200},
#  {'epoch': 7,
#   'domain_acc': 0.9921,
#   'transfer_acc': 0.3647,
#   'blue': 0.8311,
#   'iteration': 300},
#  {'epoch': 7,
#   'domain_acc': 0.9914,
#   'transfer_acc': 0.3625,
#   'blue': 0.8364,
#   'iteration': 400},
#  {'epoch': 7,
#   'domain_acc': 0.9907,
#   'transfer_acc': 0.3635,
#   'blue': 0.8357,
#   'iteration': 500},
#  {'epoch': 7,
#   'domain_acc': 0.9902,
#   'transfer_acc': 0.3612,
#   'blue': 0.8381,
#   'iteration': 600},
#  {'epoch': 7,
#   'domain_acc': 0.9892,
#   'transfer_acc': 0.3632,
#   'blue': 0.8297,
#   'iteration': 700},
#  {'epoch': 7,
#   'domain_acc': 0.9899,
#   'transfer_acc': 0.3644,
#   'blue': 0.8338,
#   'iteration': 800},
#  {'epoch': 7,
#   'domain_acc': 0.9921,
#   'transfer_acc': 0.359,
#   'blue': 0.8392,
#   'iteration': 900},
#  {'epoch': 7,
#   'domain_acc': 0.991,
#   'transfer_acc': 0.3712,
#   'blue': 0.8385,
#   'iteration': 1000},
#  {'epoch': 7,
#   'domain_acc': 0.9914,
#   'transfer_acc': 0.3684,
#   'blue': 0.8395,
#   'iteration': 1100},
#  {'epoch': 7,
#   'domain_acc': 0.9903,
#   'transfer_acc': 0.3663,
#   'blue': 0.8404,
#   'iteration': 1200},
#  {'epoch': 7,
#   'domain_acc': 0.9894,
#   'transfer_acc': 0.3657,
#   'blue': 0.8394,
#   'iteration': 1300},
#  {'epoch': 7,
#   'domain_acc': 0.9899,
#   'transfer_acc': 0.3612,
#   'blue': 0.8407,
#   'iteration': 1400},
#  {'epoch': 7,
#   'domain_acc': 0.9904,
#   'transfer_acc': 0.3644,
#   'blue': 0.8415,
#   'iteration': 1500},
#  {'epoch': 7,
#   'domain_acc': 0.9904,
#   'transfer_acc': 0.3637,
#   'blue': 0.8404,
#   'iteration': 1600},
#  {'epoch': 7,
#   'domain_acc': 0.9908,
#   'transfer_acc': 0.3655,
#   'blue': 0.8413,
#   'iteration': 1700},
#  {'epoch': 7,
#   'domain_acc': 0.9904,
#   'transfer_acc': 0.3612,
#   'blue': 0.8439,
#   'iteration': 1800},
#  {'epoch': 7,
#   'domain_acc': 0.9901,
#   'transfer_acc': 0.3598,
#   'blue': 0.8438,
#   'iteration': 1900},
#  {'epoch': 7,
#   'domain_acc': 0.9899,
#   'transfer_acc': 0.3615,
#   'blue': 0.8449,
#   'iteration': 2000},
#  {'epoch': 7,
#   'domain_acc': 0.9902,
#   'transfer_acc': 0.3643,
#   'blue': 0.8456,
#   'iteration': 2100},
#  {'epoch': 7,
#   'domain_acc': 0.9905,
#   'transfer_acc': 0.3639,
#   'blue': 0.843,
#   'iteration': 2200},
#  {'epoch': 7,
#   'domain_acc': 0.9894,
#   'transfer_acc': 0.3594,
#   'blue': 0.8474,
#   'iteration': 2300},
#  {'epoch': 7,
#   'domain_acc': 0.991,
#   'transfer_acc': 0.3578,
#   'blue': 0.8474,
#   'iteration': 2400},
#  {'epoch': 7,
#   'domain_acc': 0.9894,
#   'transfer_acc': 0.3641,
#   'blue': 0.8402,
#   'iteration': 2500},
#  {'epoch': 7,
#   'domain_acc': 0.9897,
#   'transfer_acc': 0.3581,
#   'blue': 0.8474,
#   'iteration': 2600},
#  {'epoch': 7,
#   'domain_acc': 0.9898,
#   'transfer_acc': 0.3604,
#   'blue': 0.8481,
#   'iteration': 2700},
#  {'epoch': 7,
#   'domain_acc': 0.9891,
#   'transfer_acc': 0.356,
#   'blue': 0.8493,
#   'iteration': 2800},
#  {'epoch': 8,
#   'domain_acc': 0.9903,
#   'transfer_acc': 0.3531,
#   'blue': 0.8466,
#   'iteration': 100},
#  {'epoch': 8,
#   'domain_acc': 0.9903,
#   'transfer_acc': 0.3528,
#   'blue': 0.8485,
#   'iteration': 200},
#  {'epoch': 8,
#   'domain_acc': 0.9894,
#   'transfer_acc': 0.3533,
#   'blue': 0.8504,
#   'iteration': 300},
#  {'epoch': 8,
#   'domain_acc': 0.9897,
#   'transfer_acc': 0.3529,
#   'blue': 0.8502,
#   'iteration': 400},
#  {'epoch': 8,
#   'domain_acc': 0.9908,
#   'transfer_acc': 0.3574,
#   'blue': 0.8508,
#   'iteration': 500},
#  {'epoch': 8,
#   'domain_acc': 0.9904,
#   'transfer_acc': 0.3524,
#   'blue': 0.8497,
#   'iteration': 600},
#  {'epoch': 8,
#   'domain_acc': 0.9902,
#   'transfer_acc': 0.3533,
#   'blue': 0.8521,
#   'iteration': 700},
#  {'epoch': 8,
#   'domain_acc': 0.9904,
#   'transfer_acc': 0.3536,
#   'blue': 0.8504,
#   'iteration': 800},
#  {'epoch': 8,
#   'domain_acc': 0.9905,
#   'transfer_acc': 0.3528,
#   'blue': 0.8493,
#   'iteration': 900},
#  {'epoch': 8,
#   'domain_acc': 0.9894,
#   'transfer_acc': 0.3551,
#   'blue': 0.8513,
#   'iteration': 1000},
#  {'epoch': 8,
#   'domain_acc': 0.9903,
#   'transfer_acc': 0.3554,
#   'blue': 0.8525,
#   'iteration': 1100},
#  {'epoch': 8,
#   'domain_acc': 0.9909,
#   'transfer_acc': 0.3522,
#   'blue': 0.8529,
#   'iteration': 1200},
#  {'epoch': 8,
#   'domain_acc': 0.9904,
#   'transfer_acc': 0.356,
#   'blue': 0.8506,
#   'iteration': 1300},
#  {'epoch': 8,
#   'domain_acc': 0.9905,
#   'transfer_acc': 0.3565,
#   'blue': 0.8537,
#   'iteration': 1400},
#  {'epoch': 8,
#   'domain_acc': 0.9904,
#   'transfer_acc': 0.353,
#   'blue': 0.8513,
#   'iteration': 1500},
#  {'epoch': 8,
#   'domain_acc': 0.9902,
#   'transfer_acc': 0.356,
#   'blue': 0.8523,
#   'iteration': 1600},
#  {'epoch': 8,
#   'domain_acc': 0.9898,
#   'transfer_acc': 0.3523,
#   'blue': 0.8556,
#   'iteration': 1700},
#  {'epoch': 8,
#   'domain_acc': 0.9901,
#   'transfer_acc': 0.3501,
#   'blue': 0.8539,
#   'iteration': 1800},
#  {'epoch': 8,
#   'domain_acc': 0.9896,
#   'transfer_acc': 0.3531,
#   'blue': 0.8538,
#   'iteration': 1900},
#  {'epoch': 8,
#   'domain_acc': 0.992,
#   'transfer_acc': 0.3538,
#   'blue': 0.8541,
#   'iteration': 2000},
#  {'epoch': 8,
#   'domain_acc': 0.9899,
#   'transfer_acc': 0.3523,
#   'blue': 0.8538,
#   'iteration': 2100},
#  {'epoch': 8,
#   'domain_acc': 0.9901,
#   'transfer_acc': 0.35,
#   'blue': 0.8565,
#   'iteration': 2200},
#  {'epoch': 8,
#   'domain_acc': 0.9894,
#   'transfer_acc': 0.3519,
#   'blue': 0.8576,
#   'iteration': 2300},
#  {'epoch': 8,
#   'domain_acc': 0.9904,
#   'transfer_acc': 0.3511,
#   'blue': 0.8505,
#   'iteration': 2400},
#  {'epoch': 8,
#   'domain_acc': 0.9896,
#   'transfer_acc': 0.3476,
#   'blue': 0.8579,
#   'iteration': 2500},
#  {'epoch': 8,
#   'domain_acc': 0.9892,
#   'transfer_acc': 0.3495,
#   'blue': 0.8572,
#   'iteration': 2600},
#  {'epoch': 8,
#   'domain_acc': 0.9893,
#   'transfer_acc': 0.352,
#   'blue': 0.8582,
#   'iteration': 2700},
#  {'epoch': 8,
#   'domain_acc': 0.9902,
#   'transfer_acc': 0.3476,
#   'blue': 0.8587,
#   'iteration': 2800},
#  {'epoch': 9,
#   'domain_acc': 0.9888,
#   'transfer_acc': 0.3514,
#   'blue': 0.8594,
#   'iteration': 100},
#  {'epoch': 9,
#   'domain_acc': 0.9901,
#   'transfer_acc': 0.3486,
#   'blue': 0.8573,
#   'iteration': 200},
#  {'epoch': 9,
#   'domain_acc': 0.991,
#   'transfer_acc': 0.3485,
#   'blue': 0.8593,
#   'iteration': 300},
#  {'epoch': 9,
#   'domain_acc': 0.9901,
#   'transfer_acc': 0.3445,
#   'blue': 0.8617,
#   'iteration': 400},
#  {'epoch': 9,
#   'domain_acc': 0.9899,
#   'transfer_acc': 0.3466,
#   'blue': 0.8616,
#   'iteration': 500},
#  {'epoch': 9,
#   'domain_acc': 0.9888,
#   'transfer_acc': 0.3428,
#   'blue': 0.8621,
#   'iteration': 600},
#  {'epoch': 9,
#   'domain_acc': 0.9894,
#   'transfer_acc': 0.347,
#   'blue': 0.8585,
#   'iteration': 700},
#  {'epoch': 9,
#   'domain_acc': 0.9893,
#   'transfer_acc': 0.3476,
#   'blue': 0.8597,
#   'iteration': 800},
#  {'epoch': 9,
#   'domain_acc': 0.9878,
#   'transfer_acc': 0.3477,
#   'blue': 0.8605,
#   'iteration': 900},
#  {'epoch': 9,
#   'domain_acc': 0.9881,
#   'transfer_acc': 0.3443,
#   'blue': 0.8593,
#   'iteration': 1000},
#  {'epoch': 9,
#   'domain_acc': 0.9886,
#   'transfer_acc': 0.3495,
#   'blue': 0.8589,
#   'iteration': 1100},
#  {'epoch': 9,
#   'domain_acc': 0.9891,
#   'transfer_acc': 0.35,
#   'blue': 0.8601,
#   'iteration': 1200},
#  {'epoch': 9,
#   'domain_acc': 0.9889,
#   'transfer_acc': 0.3465,
#   'blue': 0.8608,
#   'iteration': 1300},
#  {'epoch': 9,
#   'domain_acc': 0.9881,
#   'transfer_acc': 0.346,
#   'blue': 0.8627,
#   'iteration': 1400},
#  {'epoch': 9,
#   'domain_acc': 0.9902,
#   'transfer_acc': 0.3465,
#   'blue': 0.8597,
#   'iteration': 1500},
#  {'epoch': 9,
#   'domain_acc': 0.9882,
#   'transfer_acc': 0.3459,
#   'blue': 0.8613,
#   'iteration': 1600},
#  {'epoch': 9,
#   'domain_acc': 0.9881,
#   'transfer_acc': 0.345,
#   'blue': 0.8635,
#   'iteration': 1700},
#  {'epoch': 9,
#   'domain_acc': 0.9889,
#   'transfer_acc': 0.3479,
#   'blue': 0.8619,
#   'iteration': 1800},
#  {'epoch': 9,
#   'domain_acc': 0.9885,
#   'transfer_acc': 0.3475,
#   'blue': 0.8626,
#   'iteration': 1900},
#  {'epoch': 9,
#   'domain_acc': 0.9881,
#   'transfer_acc': 0.3434,
#   'blue': 0.8626,
#   'iteration': 2000},
#  {'epoch': 9,
#   'domain_acc': 0.9892,
#   'transfer_acc': 0.3433,
#   'blue': 0.8636,
#   'iteration': 2100},
#  {'epoch': 9,
#   'domain_acc': 0.9877,
#   'transfer_acc': 0.3459,
#   'blue': 0.8651,
#   'iteration': 2200},
#  {'epoch': 9,
#   'domain_acc': 0.9886,
#   'transfer_acc': 0.3445,
#   'blue': 0.8643,
#   'iteration': 2300},
#  {'epoch': 9,
#   'domain_acc': 0.9871,
#   'transfer_acc': 0.3425,
#   'blue': 0.8649,
#   'iteration': 2400},
#  {'epoch': 9,
#   'domain_acc': 0.9877,
#   'transfer_acc': 0.3434,
#   'blue': 0.8654,
#   'iteration': 2500},
#  {'epoch': 9,
#   'domain_acc': 0.9899,
#   'transfer_acc': 0.3422,
#   'blue': 0.8642,
#   'iteration': 2600},
#  {'epoch': 9,
#   'domain_acc': 0.988,
#   'transfer_acc': 0.3475,
#   'blue': 0.8645,
#   'iteration': 2700},
#  {'epoch': 9,
#   'domain_acc': 0.9883,
#   'transfer_acc': 0.3434,
#   'blue': 0.8639,
#   'iteration': 2800},
#  {'epoch': 9,
#   'domain_acc': 0.9887,
#   'transfer_acc': 0.3474,
#   'blue': 0.8647,
#   'iteration': 2900},
#  {'epoch': 10,
#   'domain_acc': 0.9888,
#   'transfer_acc': 0.343,
#   'blue': 0.8611,
#   'iteration': 100},
#  {'epoch': 10,
#   'domain_acc': 0.9885,
#   'transfer_acc': 0.3434,
#   'blue': 0.8659,
#   'iteration': 200},
#  {'epoch': 10,
#   'domain_acc': 0.9894,
#   'transfer_acc': 0.3401,
#   'blue': 0.8678,
#   'iteration': 300},
#  {'epoch': 10,
#   'domain_acc': 0.9888,
#   'transfer_acc': 0.3436,
#   'blue': 0.8665,
#   'iteration': 400},
#  {'epoch': 10,
#   'domain_acc': 0.9889,
#   'transfer_acc': 0.3441,
#   'blue': 0.8677,
#   'iteration': 500},
#  {'epoch': 10,
#   'domain_acc': 0.9886,
#   'transfer_acc': 0.3433,
#   'blue': 0.8689,
#   'iteration': 600},
#  {'epoch': 10,
#   'domain_acc': 0.9886,
#   'transfer_acc': 0.3431,
#   'blue': 0.8689,
#   'iteration': 700},
#  {'epoch': 10,
#   'domain_acc': 0.9877,
#   'transfer_acc': 0.3383,
#   'blue': 0.8674,
#   'iteration': 800},
#  {'epoch': 10,
#   'domain_acc': 0.9889,
#   'transfer_acc': 0.3394,
#   'blue': 0.8694,
#   'iteration': 900},
#  {'epoch': 10,
#   'domain_acc': 0.9893,
#   'transfer_acc': 0.3416,
#   'blue': 0.8668,
#   'iteration': 1000},
#  {'epoch': 10,
#   'domain_acc': 0.9892,
#   'transfer_acc': 0.3391,
#   'blue': 0.8694,
#   'iteration': 1100},
#  {'epoch': 10,
#   'domain_acc': 0.9885,
#   'transfer_acc': 0.3425,
#   'blue': 0.8676,
#   'iteration': 1200},
#  {'epoch': 10,
#   'domain_acc': 0.9894,
#   'transfer_acc': 0.3458,
#   'blue': 0.8686,
#   'iteration': 1300},
#  {'epoch': 10,
#   'domain_acc': 0.9898,
#   'transfer_acc': 0.3445,
#   'blue': 0.8672,
#   'iteration': 1400},
#  {'epoch': 10,
#   'domain_acc': 0.9892,
#   'transfer_acc': 0.3422,
#   'blue': 0.8694,
#   'iteration': 1500},
#  {'epoch': 10,
#   'domain_acc': 0.9894,
#   'transfer_acc': 0.3383,
#   'blue': 0.8711,
#   'iteration': 1600},
#  {'epoch': 10,
#   'domain_acc': 0.9891,
#   'transfer_acc': 0.3437,
#   'blue': 0.8696,
#   'iteration': 1700},
#  {'epoch': 10,
#   'domain_acc': 0.9874,
#   'transfer_acc': 0.3445,
#   'blue': 0.871,
#   'iteration': 1800},
#  {'epoch': 10,
#   'domain_acc': 0.9886,
#   'transfer_acc': 0.3418,
#   'blue': 0.871,
#   'iteration': 1900},
#  {'epoch': 10,
#   'domain_acc': 0.9883,
#   'transfer_acc': 0.341,
#   'blue': 0.8708,
#   'iteration': 2000},
#  {'epoch': 10,
#   'domain_acc': 0.9891,
#   'transfer_acc': 0.3417,
#   'blue': 0.8702,
#   'iteration': 2100},
#  {'epoch': 10,
#   'domain_acc': 0.9891,
#   'transfer_acc': 0.3409,
#   'blue': 0.8722,
#   'iteration': 2200},
#  {'epoch': 10,
#   'domain_acc': 0.9891,
#   'transfer_acc': 0.3432,
#   'blue': 0.8695,
#   'iteration': 2300},
#  {'epoch': 10,
#   'domain_acc': 0.9883,
#   'transfer_acc': 0.3385,
#   'blue': 0.8724,
#   'iteration': 2400},
#  {'epoch': 10,
#   'domain_acc': 0.9891,
#   'transfer_acc': 0.3389,
#   'blue': 0.8711,
#   'iteration': 2500},
#  {'epoch': 10,
#   'domain_acc': 0.9889,
#   'transfer_acc': 0.3388,
#   'blue': 0.8711,
#   'iteration': 2600},
#  {'epoch': 10,
#   'domain_acc': 0.9882,
#   'transfer_acc': 0.3418,
#   'blue': 0.8722,
#   'iteration': 2700},
#  {'epoch': 10,
#   'domain_acc': 0.9878,
#   'transfer_acc': 0.3442,
#   'blue': 0.8743,
#   'iteration': 2800},
#  {'epoch': 11,
#   'domain_acc': 0.9799,
#   'transfer_acc': 0.5771,
#   'blue': 0.593,
#   'iteration': 100},
#  {'epoch': 11,
#   'domain_acc': 0.9872,
#   'transfer_acc': 0.7216,
#   'blue': 0.5233,
#   'iteration': 200},
#  {'epoch': 11,
#   'domain_acc': 0.9851,
#   'transfer_acc': 0.7177,
#   'blue': 0.5662,
#   'iteration': 300},
#  {'epoch': 11,
#   'domain_acc': 0.9842,
#   'transfer_acc': 0.7111,
#   'blue': 0.6134,
#   'iteration': 400},
#  {'epoch': 11,
#   'domain_acc': 0.9838,
#   'transfer_acc': 0.7811,
#   'blue': 0.5895,
#   'iteration': 500},
#  {'epoch': 11,
#   'domain_acc': 0.9813,
#   'transfer_acc': 0.7563,
#   'blue': 0.63,
#   'iteration': 600},
#  {'epoch': 11,
#   'domain_acc': 0.9883,
#   'transfer_acc': 0.7807,
#   'blue': 0.6115,
#   'iteration': 700},
#  {'epoch': 11,
#   'domain_acc': 0.9925,
#   'transfer_acc': 0.7446,
#   'blue': 0.6208,
#   'iteration': 800},
#  {'epoch': 11,
#   'domain_acc': 0.9877,
#   'transfer_acc': 0.7657,
#   'blue': 0.6203,
#   'iteration': 900},
#  {'epoch': 11,
#   'domain_acc': 0.9882,
#   'transfer_acc': 0.7575,
#   'blue': 0.6414,
#   'iteration': 1000},
#  {'epoch': 11,
#   'domain_acc': 0.9918,
#   'transfer_acc': 0.77,
#   'blue': 0.6225,
#   'iteration': 1100},
#  {'epoch': 11,
#   'domain_acc': 0.992,
#   'transfer_acc': 0.7656,
#   'blue': 0.6354,
#   'iteration': 1200},
#  {'epoch': 11,
#   'domain_acc': 0.9928,
#   'transfer_acc': 0.7865,
#   'blue': 0.6105,
#   'iteration': 1300},
#  {'epoch': 11,
#   'domain_acc': 0.9919,
#   'transfer_acc': 0.7808,
#   'blue': 0.6266,
#   'iteration': 1400},
#  {'epoch': 11,
#   'domain_acc': 0.994,
#   'transfer_acc': 0.7962,
#   'blue': 0.6241,
#   'iteration': 1500},
#  {'epoch': 11,
#   'domain_acc': 0.9904,
#   'transfer_acc': 0.7698,
#   'blue': 0.6397,
#   'iteration': 1600},
#  {'epoch': 11,
#   'domain_acc': 0.991,
#   'transfer_acc': 0.7938,
#   'blue': 0.6034,
#   'iteration': 1700},
#  {'epoch': 11,
#   'domain_acc': 0.9928,
#   'transfer_acc': 0.7774,
#   'blue': 0.6246,
#   'iteration': 1800},
#  {'epoch': 11,
#   'domain_acc': 0.9904,
#   'transfer_acc': 0.7933,
#   'blue': 0.6198,
#   'iteration': 1900},
#  {'epoch': 11,
#   'domain_acc': 0.9892,
#   'transfer_acc': 0.7601,
#   'blue': 0.6513,
#   'iteration': 2000},
#  {'epoch': 11,
#   'domain_acc': 0.9928,
#   'transfer_acc': 0.776,
#   'blue': 0.631,
#   'iteration': 2100},
#  {'epoch': 11,
#   'domain_acc': 0.9919,
#   'transfer_acc': 0.7967,
#   'blue': 0.6334,
#   'iteration': 2200},
#  {'epoch': 11,
#   'domain_acc': 0.9935,
#   'transfer_acc': 0.813,
#   'blue': 0.6255,
#   'iteration': 2300},
#  {'epoch': 11,
#   'domain_acc': 0.9935,
#   'transfer_acc': 0.825,
#   'blue': 0.5959,
#   'iteration': 2400},
#  {'epoch': 11,
#   'domain_acc': 0.9944,
#   'transfer_acc': 0.8512,
#   'blue': 0.599,
#   'iteration': 2500},
#  {'epoch': 11,
#   'domain_acc': 0.9923,
#   'transfer_acc': 0.793,
#   'blue': 0.6417,
#   'iteration': 2600},
#  {'epoch': 11,
#   'domain_acc': 0.9937,
#   'transfer_acc': 0.8277,
#   'blue': 0.6184,
#   'iteration': 2700},
#  {'epoch': 11,
#   'domain_acc': 0.9924,
#   'transfer_acc': 0.8288,
#   'blue': 0.6254,
#   'iteration': 2800},
#  {'epoch': 12,
#   'domain_acc': 0.9912,
#   'transfer_acc': 0.7913,
#   'blue': 0.6433,
#   'iteration': 100},
#  {'epoch': 12,
#   'domain_acc': 0.9914,
#   'transfer_acc': 0.817,
#   'blue': 0.617,
#   'iteration': 200},
#  {'epoch': 12,
#   'domain_acc': 0.9946,
#   'transfer_acc': 0.7927,
#   'blue': 0.6285,
#   'iteration': 300},
#  {'epoch': 12,
#   'domain_acc': 0.9939,
#   'transfer_acc': 0.8121,
#   'blue': 0.6241,
#   'iteration': 400},
#  {'epoch': 12,
#   'domain_acc': 0.9925,
#   'transfer_acc': 0.7759,
#   'blue': 0.6453,
#   'iteration': 500},
#  {'epoch': 12,
#   'domain_acc': 0.9934,
#   'transfer_acc': 0.8283,
#   'blue': 0.6089,
#   'iteration': 600},
#  {'epoch': 12,
#   'domain_acc': 0.9928,
#   'transfer_acc': 0.7903,
#   'blue': 0.6388,
#   'iteration': 700},
#  {'epoch': 12,
#   'domain_acc': 0.9935,
#   'transfer_acc': 0.8395,
#   'blue': 0.6114,
#   'iteration': 800},
#  {'epoch': 12,
#   'domain_acc': 0.9931,
#   'transfer_acc': 0.7957,
#   'blue': 0.6315,
#   'iteration': 900},
#  {'epoch': 12,
#   'domain_acc': 0.9935,
#   'transfer_acc': 0.8269,
#   'blue': 0.6119,
#   'iteration': 1000},
#  {'epoch': 12,
#   'domain_acc': 0.9928,
#   'transfer_acc': 0.7927,
#   'blue': 0.6391,
#   'iteration': 1100},
#  {'epoch': 12,
#   'domain_acc': 0.9929,
#   'transfer_acc': 0.8298,
#   'blue': 0.6112,
#   'iteration': 1200},
#  {'epoch': 12,
#   'domain_acc': 0.9952,
#   'transfer_acc': 0.8296,
#   'blue': 0.6113,
#   'iteration': 1300},
#  {'epoch': 12,
#   'domain_acc': 0.9952,
#   'transfer_acc': 0.8472,
#   'blue': 0.6143,
#   'iteration': 1400},
#  {'epoch': 12,
#   'domain_acc': 0.9944,
#   'transfer_acc': 0.8341,
#   'blue': 0.6058,
#   'iteration': 1500},
#  {'epoch': 12,
#   'domain_acc': 0.9948,
#   'transfer_acc': 0.803,
#   'blue': 0.6267,
#   'iteration': 1600},
#  {'epoch': 12,
#   'domain_acc': 0.9955,
#   'transfer_acc': 0.8619,
#   'blue': 0.6044,
#   'iteration': 1700},
#  {'epoch': 12,
#   'domain_acc': 0.9958,
#   'transfer_acc': 0.8346,
#   'blue': 0.6201,
#   'iteration': 1800},
#  {'epoch': 12,
#   'domain_acc': 0.994,
#   'transfer_acc': 0.8287,
#   'blue': 0.6206,
#   'iteration': 1900},
#  {'epoch': 12,
#   'domain_acc': 0.9934,
#   'transfer_acc': 0.8274,
#   'blue': 0.6304,
#   'iteration': 2000},
#  {'epoch': 12,
#   'domain_acc': 0.9928,
#   'transfer_acc': 0.8237,
#   'blue': 0.6272,
#   'iteration': 2100},
#  {'epoch': 12,
#   'domain_acc': 0.9937,
#   'transfer_acc': 0.8221,
#   'blue': 0.632,
#   'iteration': 2200},
#  {'epoch': 12,
#   'domain_acc': 0.9937,
#   'transfer_acc': 0.8477,
#   'blue': 0.6176,
#   'iteration': 2300},
#  {'epoch': 12,
#   'domain_acc': 0.9937,
#   'transfer_acc': 0.8574,
#   'blue': 0.6247,
#   'iteration': 2400},
#  {'epoch': 12,
#   'domain_acc': 0.9925,
#   'transfer_acc': 0.8228,
#   'blue': 0.6251,
#   'iteration': 2500},
#  {'epoch': 12,
#   'domain_acc': 0.9905,
#   'transfer_acc': 0.8307,
#   'blue': 0.6172,
#   'iteration': 2600},
#  {'epoch': 12,
#   'domain_acc': 0.993,
#   'transfer_acc': 0.8464,
#   'blue': 0.6169,
#   'iteration': 2700},
#  {'epoch': 12,
#   'domain_acc': 0.9892,
#   'transfer_acc': 0.8368,
#   'blue': 0.6274,
#   'iteration': 2800},
#  {'epoch': 12,
#   'domain_acc': 0.9919,
#   'transfer_acc': 0.8296,
#   'blue': 0.6175,
#   'iteration': 2900},
#  {'epoch': 13,
#   'domain_acc': 0.9905,
#   'transfer_acc': 0.8703,
#   'blue': 0.5931,
#   'iteration': 100},
#  {'epoch': 13,
#   'domain_acc': 0.992,
#   'transfer_acc': 0.8571,
#   'blue': 0.6065,
#   'iteration': 200},
#  {'epoch': 13,
#   'domain_acc': 0.9914,
#   'transfer_acc': 0.8415,
#   'blue': 0.6201,
#   'iteration': 300},
#  {'epoch': 13,
#   'domain_acc': 0.9894,
#   'transfer_acc': 0.8351,
#   'blue': 0.6166,
#   'iteration': 400},
#  {'epoch': 13,
#   'domain_acc': 0.9929,
#   'transfer_acc': 0.8527,
#   'blue': 0.5986,
#   'iteration': 500},
#  {'epoch': 13,
#   'domain_acc': 0.9924,
#   'transfer_acc': 0.8231,
#   'blue': 0.6199,
#   'iteration': 600},
#  {'epoch': 13,
#   'domain_acc': 0.9929,
#   'transfer_acc': 0.8485,
#   'blue': 0.6033,
#   'iteration': 700},
#  {'epoch': 13,
#   'domain_acc': 0.9908,
#   'transfer_acc': 0.8721,
#   'blue': 0.5984,
#   'iteration': 800},
#  {'epoch': 13,
#   'domain_acc': 0.9921,
#   'transfer_acc': 0.8272,
#   'blue': 0.6271,
#   'iteration': 900},
#  {'epoch': 13,
#   'domain_acc': 0.9913,
#   'transfer_acc': 0.8665,
#   'blue': 0.6121,
#   'iteration': 1000},
#  {'epoch': 13,
#   'domain_acc': 0.993,
#   'transfer_acc': 0.8296,
#   'blue': 0.626,
#   'iteration': 1100},
#  {'epoch': 13,
#   'domain_acc': 0.9924,
#   'transfer_acc': 0.8371,
#   'blue': 0.6213,
#   'iteration': 1200},
#  {'epoch': 13,
#   'domain_acc': 0.9921,
#   'transfer_acc': 0.8647,
#   'blue': 0.5966,
#   'iteration': 1300},
#  {'epoch': 13,
#   'domain_acc': 0.9928,
#   'transfer_acc': 0.8556,
#   'blue': 0.6022,
#   'iteration': 1400},
#  {'epoch': 13,
#   'domain_acc': 0.9934,
#   'transfer_acc': 0.8439,
#   'blue': 0.6209,
#   'iteration': 1500},
#  {'epoch': 13,
#   'domain_acc': 0.9941,
#   'transfer_acc': 0.8389,
#   'blue': 0.6179,
#   'iteration': 1600},
#  {'epoch': 13,
#   'domain_acc': 0.9944,
#   'transfer_acc': 0.8515,
#   'blue': 0.6056,
#   'iteration': 1700},
#  {'epoch': 13,
#   'domain_acc': 0.9944,
#   'transfer_acc': 0.8523,
#   'blue': 0.6179,
#   'iteration': 1800},
#  {'epoch': 13,
#   'domain_acc': 0.9937,
#   'transfer_acc': 0.82,
#   'blue': 0.6318,
#   'iteration': 1900},
#  {'epoch': 13,
#   'domain_acc': 0.9918,
#   'transfer_acc': 0.8512,
#   'blue': 0.6131,
#   'iteration': 2000},
#  {'epoch': 13,
#   'domain_acc': 0.9914,
#   'transfer_acc': 0.8702,
#   'blue': 0.5834,
#   'iteration': 2100},
#  {'epoch': 13,
#   'domain_acc': 0.9934,
#   'transfer_acc': 0.8269,
#   'blue': 0.6208,
#   'iteration': 2200},
#  {'epoch': 13,
#   'domain_acc': 0.9935,
#   'transfer_acc': 0.8411,
#   'blue': 0.6271,
#   'iteration': 2300},
#  {'epoch': 13,
#   'domain_acc': 0.9919,
#   'transfer_acc': 0.8644,
#   'blue': 0.6128,
#   'iteration': 2400},
#  {'epoch': 13,
#   'domain_acc': 0.9948,
#   'transfer_acc': 0.8717,
#   'blue': 0.5999,
#   'iteration': 2500},
#  {'epoch': 13,
#   'domain_acc': 0.9902,
#   'transfer_acc': 0.862,
#   'blue': 0.612,
#   'iteration': 2600},
#  {'epoch': 13,
#   'domain_acc': 0.9926,
#   'transfer_acc': 0.8475,
#   'blue': 0.6202,
#   'iteration': 2700},
#  {'epoch': 13,
#   'domain_acc': 0.9897,
#   'transfer_acc': 0.8533,
#   'blue': 0.6085,
#   'iteration': 2800},
#  {'epoch': 14,
#   'domain_acc': 0.9945,
#   'transfer_acc': 0.8461,
#   'blue': 0.6089,
#   'iteration': 100},
#  {'epoch': 14,
#   'domain_acc': 0.9918,
#   'transfer_acc': 0.8552,
#   'blue': 0.6061,
#   'iteration': 200},
#  {'epoch': 14,
#   'domain_acc': 0.9934,
#   'transfer_acc': 0.8635,
#   'blue': 0.6109,
#   'iteration': 300},
#  {'epoch': 14,
#   'domain_acc': 0.9931,
#   'transfer_acc': 0.8593,
#   'blue': 0.6109,
#   'iteration': 400},
#  {'epoch': 14,
#   'domain_acc': 0.9925,
#   'transfer_acc': 0.8534,
#   'blue': 0.6135,
#   'iteration': 500},
#  {'epoch': 14,
#   'domain_acc': 0.9942,
#   'transfer_acc': 0.8609,
#   'blue': 0.6092,
#   'iteration': 600},
#  {'epoch': 14,
#   'domain_acc': 0.9936,
#   'transfer_acc': 0.8495,
#   'blue': 0.6211,
#   'iteration': 700},
#  {'epoch': 14,
#   'domain_acc': 0.9914,
#   'transfer_acc': 0.8595,
#   'blue': 0.614,
#   'iteration': 800},
#  {'epoch': 14,
#   'domain_acc': 0.993,
#   'transfer_acc': 0.8604,
#   'blue': 0.6069,
#   'iteration': 900},
#  {'epoch': 14,
#   'domain_acc': 0.9919,
#   'transfer_acc': 0.8479,
#   'blue': 0.6017,
#   'iteration': 1000},
#  {'epoch': 14,
#   'domain_acc': 0.9913,
#   'transfer_acc': 0.8966,
#   'blue': 0.5768,
#   'iteration': 1100},
#  {'epoch': 14,
#   'domain_acc': 0.9935,
#   'transfer_acc': 0.9086,
#   'blue': 0.5692,
#   'iteration': 1200},
#  {'epoch': 14,
#   'domain_acc': 0.9924,
#   'transfer_acc': 0.8738,
#   'blue': 0.5958,
#   'iteration': 1300},
#  {'epoch': 14,
#   'domain_acc': 0.994,
#   'transfer_acc': 0.8601,
#   'blue': 0.5981,
#   'iteration': 1400},
#  {'epoch': 14,
#   'domain_acc': 0.9929,
#   'transfer_acc': 0.8434,
#   'blue': 0.6059,
#   'iteration': 1500},
#  {'epoch': 14,
#   'domain_acc': 0.9932,
#   'transfer_acc': 0.8664,
#   'blue': 0.5986,
#   'iteration': 1600},
#  {'epoch': 14,
#   'domain_acc': 0.994,
#   'transfer_acc': 0.8625,
#   'blue': 0.614,
#   'iteration': 1700},
#  {'epoch': 14,
#   'domain_acc': 0.9915,
#   'transfer_acc': 0.8669,
#   'blue': 0.6098,
#   'iteration': 1800},
#  {'epoch': 14,
#   'domain_acc': 0.9915,
#   'transfer_acc': 0.8627,
#   'blue': 0.5934,
#   'iteration': 1900},
#  {'epoch': 14,
#   'domain_acc': 0.9923,
#   'transfer_acc': 0.8546,
#   'blue': 0.6147,
#   'iteration': 2000},
#  {'epoch': 14,
#   'domain_acc': 0.9931,
#   'transfer_acc': 0.8581,
#   'blue': 0.6163,
#   'iteration': 2100},
#  {'epoch': 14,
#   'domain_acc': 0.9926,
#   'transfer_acc': 0.8717,
#   'blue': 0.6003,
#   'iteration': 2200},
#  {'epoch': 14,
#   'domain_acc': 0.9945,
#   'transfer_acc': 0.8778,
#   'blue': 0.5973,
#   'iteration': 2300},
#  {'epoch': 14,
#   'domain_acc': 0.9937,
#   'transfer_acc': 0.8752,
#   'blue': 0.5973,
#   'iteration': 2400},
#  {'epoch': 14,
#   'domain_acc': 0.9928,
#   'transfer_acc': 0.8608,
#   'blue': 0.616,
#   'iteration': 2500},
#  {'epoch': 14,
#   'domain_acc': 0.9951,
#   'transfer_acc': 0.8832,
#   'blue': 0.5704,
#   'iteration': 2600},
#  {'epoch': 14,
#   'domain_acc': 0.9958,
#   'transfer_acc': 0.8862,
#   'blue': 0.5834,
#   'iteration': 2700},
#  {'epoch': 14,
#   'domain_acc': 0.995,
#   'transfer_acc': 0.8889,
#   'blue': 0.5858,
#   'iteration': 2800},
#  {'epoch': 15,
#   'domain_acc': 0.9939,
#   'transfer_acc': 0.8905,
#   'blue': 0.5852,
#   'iteration': 100},
#  {'epoch': 15,
#   'domain_acc': 0.9928,
#   'transfer_acc': 0.8944,
#   'blue': 0.5849,
#   'iteration': 200},
#  {'epoch': 15,
#   'domain_acc': 0.9931,
#   'transfer_acc': 0.8633,
#   'blue': 0.6151,
#   'iteration': 300},
#  {'epoch': 15,
#   'domain_acc': 0.9956,
#   'transfer_acc': 0.8689,
#   'blue': 0.6178,
#   'iteration': 400},
#  {'epoch': 15,
#   'domain_acc': 0.9934,
#   'transfer_acc': 0.8816,
#   'blue': 0.596,
#   'iteration': 500},
#  {'epoch': 15,
#   'domain_acc': 0.9937,
#   'transfer_acc': 0.8845,
#   'blue': 0.6071,
#   'iteration': 600},
#  {'epoch': 15,
#   'domain_acc': 0.9948,
#   'transfer_acc': 0.8712,
#   'blue': 0.618,
#   'iteration': 700},
#  {'epoch': 15,
#   'domain_acc': 0.9942,
#   'transfer_acc': 0.8819,
#   'blue': 0.6056,
#   'iteration': 800},
#  {'epoch': 15,
#   'domain_acc': 0.9948,
#   'transfer_acc': 0.8707,
#   'blue': 0.6128,
#   'iteration': 900},
#  {'epoch': 15,
#   'domain_acc': 0.9956,
#   'transfer_acc': 0.8534,
#   'blue': 0.6213,
#   'iteration': 1000},
#  {'epoch': 15,
#   'domain_acc': 0.994,
#   'transfer_acc': 0.8684,
#   'blue': 0.6082,
#   'iteration': 1100},
#  {'epoch': 15,
#   'domain_acc': 0.9947,
#   'transfer_acc': 0.9145,
#   'blue': 0.5561,
#   'iteration': 1200},
#  {'epoch': 15,
#   'domain_acc': 0.9961,
#   'transfer_acc': 0.8835,
#   'blue': 0.5902,
#   'iteration': 1300},
#  {'epoch': 15,
#   'domain_acc': 0.9958,
#   'transfer_acc': 0.8775,
#   'blue': 0.5958,
#   'iteration': 1400},
#  {'epoch': 15,
#   'domain_acc': 0.9942,
#   'transfer_acc': 0.8858,
#   'blue': 0.5952,
#   'iteration': 1500},
#  {'epoch': 15,
#   'domain_acc': 0.9961,
#   'transfer_acc': 0.901,
#   'blue': 0.5894,
#   'iteration': 1600},
#  {'epoch': 15,
#   'domain_acc': 0.9952,
#   'transfer_acc': 0.9021,
#   'blue': 0.5845,
#   'iteration': 1700},
#  {'epoch': 15,
#   'domain_acc': 0.9942,
#   'transfer_acc': 0.8847,
#   'blue': 0.5876,
#   'iteration': 1800},
#  {'epoch': 15,
#   'domain_acc': 0.9934,
#   'transfer_acc': 0.8841,
#   'blue': 0.5984,
#   'iteration': 1900},
#  {'epoch': 15,
#   'domain_acc': 0.9918,
#   'transfer_acc': 0.8831,
#   'blue': 0.5888,
#   'iteration': 2000},
#  {'epoch': 15,
#   'domain_acc': 0.9946,
#   'transfer_acc': 0.9139,
#   'blue': 0.5699,
#   'iteration': 2100},
#  {'epoch': 15,
#   'domain_acc': 0.9942,
#   'transfer_acc': 0.8584,
#   'blue': 0.6056,
#   'iteration': 2200},
#  {'epoch': 15,
#   'domain_acc': 0.9939,
#   'transfer_acc': 0.8846,
#   'blue': 0.5965,
#   'iteration': 2300},
#  {'epoch': 15,
#   'domain_acc': 0.994,
#   'transfer_acc': 0.8732,
#   'blue': 0.6085,
#   'iteration': 2400},
#  {'epoch': 15,
#   'domain_acc': 0.9951,
#   'transfer_acc': 0.8805,
#   'blue': 0.6041,
#   'iteration': 2500},
#  {'epoch': 15,
#   'domain_acc': 0.9935,
#   'transfer_acc': 0.8691,
#   'blue': 0.6059,
#   'iteration': 2600},
#  {'epoch': 15,
#   'domain_acc': 0.9937,
#   'transfer_acc': 0.8832,
#   'blue': 0.607,
#   'iteration': 2700},
#  {'epoch': 15,
#   'domain_acc': 0.9942,
#   'transfer_acc': 0.904,
#   'blue': 0.5744,
#   'iteration': 2800},
#  {'epoch': 15,
#   'domain_acc': 0.9941,
#   'transfer_acc': 0.9097,
#   'blue': 0.5675,
#   'iteration': 2900},
#  {'epoch': 16,
#   'domain_acc': 0.9921,
#   'transfer_acc': 0.8825,
#   'blue': 0.6102,
#   'iteration': 100},
#  {'epoch': 16,
#   'domain_acc': 0.9942,
#   'transfer_acc': 0.8966,
#   'blue': 0.5912,
#   'iteration': 200},
#  {'epoch': 16,
#   'domain_acc': 0.9928,
#   'transfer_acc': 0.8712,
#   'blue': 0.6251,
#   'iteration': 300},
#  {'epoch': 16,
#   'domain_acc': 0.9935,
#   'transfer_acc': 0.883,
#   'blue': 0.602,
#   'iteration': 400},
#  {'epoch': 16,
#   'domain_acc': 0.9941,
#   'transfer_acc': 0.8825,
#   'blue': 0.6035,
#   'iteration': 500},
#  {'epoch': 16,
#   'domain_acc': 0.9937,
#   'transfer_acc': 0.8949,
#   'blue': 0.5838,
#   'iteration': 600},
#  {'epoch': 16,
#   'domain_acc': 0.9931,
#   'transfer_acc': 0.8835,
#   'blue': 0.5978,
#   'iteration': 700},
#  {'epoch': 16,
#   'domain_acc': 0.9936,
#   'transfer_acc': 0.8845,
#   'blue': 0.5983,
#   'iteration': 800},
#  {'epoch': 16,
#   'domain_acc': 0.9951,
#   'transfer_acc': 0.8717,
#   'blue': 0.6027,
#   'iteration': 900},
#  {'epoch': 16,
#   'domain_acc': 0.9942,
#   'transfer_acc': 0.8868,
#   'blue': 0.5952,
#   'iteration': 1000},
#  {'epoch': 16,
#   'domain_acc': 0.9945,
#   'transfer_acc': 0.8624,
#   'blue': 0.6092,
#   'iteration': 1100},
#  {'epoch': 16,
#   'domain_acc': 0.9945,
#   'transfer_acc': 0.8926,
#   'blue': 0.588,
#   'iteration': 1200},
#  {'epoch': 16,
#   'domain_acc': 0.9936,
#   'transfer_acc': 0.8755,
#   'blue': 0.5962,
#   'iteration': 1300},
#  {'epoch': 16,
#   'domain_acc': 0.9936,
#   'transfer_acc': 0.8718,
#   'blue': 0.5977,
#   'iteration': 1400},
#  {'epoch': 16,
#   'domain_acc': 0.9939,
#   'transfer_acc': 0.8965,
#   'blue': 0.5815,
#   'iteration': 1500},
#  {'epoch': 16,
#   'domain_acc': 0.9934,
#   'transfer_acc': 0.8964,
#   'blue': 0.587,
#   'iteration': 1600},
#  {'epoch': 16,
#   'domain_acc': 0.9935,
#   'transfer_acc': 0.8922,
#   'blue': 0.587,
#   'iteration': 1700},
#  {'epoch': 16,
#   'domain_acc': 0.9953,
#   'transfer_acc': 0.8558,
#   'blue': 0.6124,
#   'iteration': 1800},
#  {'epoch': 16,
#   'domain_acc': 0.9945,
#   'transfer_acc': 0.8881,
#   'blue': 0.6009,
#   'iteration': 1900},
#  {'epoch': 16,
#   'domain_acc': 0.9941,
#   'transfer_acc': 0.882,
#   'blue': 0.5997,
#   'iteration': 2000},
#  {'epoch': 16,
#   'domain_acc': 0.9951,
#   'transfer_acc': 0.8868,
#   'blue': 0.5881,
#   'iteration': 2100},
#  {'epoch': 16,
#   'domain_acc': 0.9948,
#   'transfer_acc': 0.894,
#   'blue': 0.5948,
#   'iteration': 2200},
#  {'epoch': 16,
#   'domain_acc': 0.9937,
#   'transfer_acc': 0.8879,
#   'blue': 0.5957,
#   'iteration': 2300},
#  {'epoch': 16,
#   'domain_acc': 0.9926,
#   'transfer_acc': 0.8856,
#   'blue': 0.5954,
#   'iteration': 2400},
#  {'epoch': 16,
#   'domain_acc': 0.9932,
#   'transfer_acc': 0.8744,
#   'blue': 0.594,
#   'iteration': 2500},
#  {'epoch': 16,
#   'domain_acc': 0.9945,
#   'transfer_acc': 0.8915,
#   'blue': 0.5861,
#   'iteration': 2600},
#  {'epoch': 16,
#   'domain_acc': 0.9932,
#   'transfer_acc': 0.8971,
#   'blue': 0.5804,
#   'iteration': 2700},
#  {'epoch': 16,
#   'domain_acc': 0.9942,
#   'transfer_acc': 0.8939,
#   'blue': 0.5775,
#   'iteration': 2800},
#  {'epoch': 17,
#   'domain_acc': 0.9946,
#   'transfer_acc': 0.8664,
#   'blue': 0.5942,
#   'iteration': 100},
#  {'epoch': 17,
#   'domain_acc': 0.9966,
#   'transfer_acc': 0.8779,
#   'blue': 0.5877,
#   'iteration': 200},
#  {'epoch': 17,
#   'domain_acc': 0.9946,
#   'transfer_acc': 0.9101,
#   'blue': 0.566,
#   'iteration': 300},
#  {'epoch': 17,
#   'domain_acc': 0.9941,
#   'transfer_acc': 0.8951,
#   'blue': 0.5833,
#   'iteration': 400},
#  {'epoch': 17,
#   'domain_acc': 0.9955,
#   'transfer_acc': 0.8822,
#   'blue': 0.5828,
#   'iteration': 500},
#  {'epoch': 17,
#   'domain_acc': 0.9956,
#   'transfer_acc': 0.8806,
#   'blue': 0.5969,
#   'iteration': 600},
#  {'epoch': 17,
#   'domain_acc': 0.9946,
#   'transfer_acc': 0.9056,
#   'blue': 0.5761,
#   'iteration': 700},
#  {'epoch': 17,
#   'domain_acc': 0.9946,
#   'transfer_acc': 0.8764,
#   'blue': 0.6071,
#   'iteration': 800},
#  {'epoch': 17,
#   'domain_acc': 0.9939,
#   'transfer_acc': 0.8905,
#   'blue': 0.5846,
#   'iteration': 900},
#  {'epoch': 17,
#   'domain_acc': 0.9948,
#   'transfer_acc': 0.8949,
#   'blue': 0.5922,
#   'iteration': 1000},
#  {'epoch': 17,
#   'domain_acc': 0.9948,
#   'transfer_acc': 0.8928,
#   'blue': 0.6032,
#   'iteration': 1100},
#  {'epoch': 17,
#   'domain_acc': 0.9947,
#   'transfer_acc': 0.8841,
#   'blue': 0.6024,
#   'iteration': 1200},
#  {'epoch': 17,
#   'domain_acc': 0.9948,
#   'transfer_acc': 0.9015,
#   'blue': 0.5726,
#   'iteration': 1300},
#  {'epoch': 17,
#   'domain_acc': 0.9956,
#   'transfer_acc': 0.9066,
#   'blue': 0.5786,
#   'iteration': 1400},
#  {'epoch': 17,
#   'domain_acc': 0.9923,
#   'transfer_acc': 0.8983,
#   'blue': 0.5721,
#   'iteration': 1500},
#  {'epoch': 17,
#   'domain_acc': 0.9917,
#   'transfer_acc': 0.8918,
#   'blue': 0.5823,
#   'iteration': 1600},
#  {'epoch': 17,
#   'domain_acc': 0.9915,
#   'transfer_acc': 0.895,
#   'blue': 0.5911,
#   'iteration': 1700},
#  {'epoch': 17,
#   'domain_acc': 0.9913,
#   'transfer_acc': 0.9031,
#   'blue': 0.5878,
#   'iteration': 1800},
#  {'epoch': 17,
#   'domain_acc': 0.9935,
#   'transfer_acc': 0.8757,
#   'blue': 0.598,
#   'iteration': 1900},
#  {'epoch': 17,
#   'domain_acc': 0.992,
#   'transfer_acc': 0.894,
#   'blue': 0.5818,
#   'iteration': 2000},
#  {'epoch': 17,
#   'domain_acc': 0.9932,
#   'transfer_acc': 0.8935,
#   'blue': 0.5852,
#   'iteration': 2100},
#  {'epoch': 17,
#   'domain_acc': 0.9963,
#   'transfer_acc': 0.8958,
#   'blue': 0.5789,
#   'iteration': 2200},
#  {'epoch': 17,
#   'domain_acc': 0.9945,
#   'transfer_acc': 0.8712,
#   'blue': 0.6015,
#   'iteration': 2300},
#  {'epoch': 17,
#   'domain_acc': 0.9925,
#   'transfer_acc': 0.8897,
#   'blue': 0.5841,
#   'iteration': 2400},
#  {'epoch': 17,
#   'domain_acc': 0.994,
#   'transfer_acc': 0.9093,
#   'blue': 0.5625,
#   'iteration': 2500},
#  {'epoch': 17,
#   'domain_acc': 0.9929,
#   'transfer_acc': 0.88,
#   'blue': 0.6032,
#   'iteration': 2600},
#  {'epoch': 17,
#   'domain_acc': 0.9948,
#   'transfer_acc': 0.8885,
#   'blue': 0.5877,
#   'iteration': 2700},
#  {'epoch': 17,
#   'domain_acc': 0.9962,
#   'transfer_acc': 0.8775,
#   'blue': 0.5907,
#   'iteration': 2800},
#  {'epoch': 18,
#   'domain_acc': 0.9942,
#   'transfer_acc': 0.8756,
#   'blue': 0.6083,
#   'iteration': 100},
#  {'epoch': 18,
#   'domain_acc': 0.9941,
#   'transfer_acc': 0.894,
#   'blue': 0.5824,
#   'iteration': 200},
#  {'epoch': 18,
#   'domain_acc': 0.9941,
#   'transfer_acc': 0.9013,
#   'blue': 0.5763,
#   'iteration': 300},
#  {'epoch': 18,
#   'domain_acc': 0.9932,
#   'transfer_acc': 0.8959,
#   'blue': 0.5807,
#   'iteration': 400},
#  {'epoch': 18,
#   'domain_acc': 0.9946,
#   'transfer_acc': 0.9093,
#   'blue': 0.5624,
#   'iteration': 500},
#  {'epoch': 18,
#   'domain_acc': 0.9946,
#   'transfer_acc': 0.905,
#   'blue': 0.5582,
#   'iteration': 600},
#  {'epoch': 18,
#   'domain_acc': 0.9946,
#   'transfer_acc': 0.8999,
#   'blue': 0.5801,
#   'iteration': 700},
#  {'epoch': 18,
#   'domain_acc': 0.9952,
#   'transfer_acc': 0.8994,
#   'blue': 0.5732,
#   'iteration': 800},
#  {'epoch': 18,
#   'domain_acc': 0.9967,
#   'transfer_acc': 0.8955,
#   'blue': 0.5697,
#   'iteration': 900},
#  {'epoch': 18,
#   'domain_acc': 0.9952,
#   'transfer_acc': 0.9111,
#   'blue': 0.5508,
#   'iteration': 1000},
#  {'epoch': 18,
#   'domain_acc': 0.9952,
#   'transfer_acc': 0.8915,
#   'blue': 0.578,
#   'iteration': 1100},
#  {'epoch': 18,
#   'domain_acc': 0.9945,
#   'transfer_acc': 0.8795,
#   'blue': 0.594,
#   'iteration': 1200},
#  {'epoch': 18,
#   'domain_acc': 0.9952,
#   'transfer_acc': 0.9084,
#   'blue': 0.5638,
#   'iteration': 1300},
#  {'epoch': 18,
#   'domain_acc': 0.9966,
#   'transfer_acc': 0.911,
#   'blue': 0.5614,
#   'iteration': 1400},
#  {'epoch': 18,
#   'domain_acc': 0.9945,
#   'transfer_acc': 0.8886,
#   'blue': 0.583,
#   'iteration': 1500},
#  {'epoch': 18,
#   'domain_acc': 0.995,
#   'transfer_acc': 0.9028,
#   'blue': 0.5697,
#   'iteration': 1600},
#  {'epoch': 18,
#   'domain_acc': 0.993,
#   'transfer_acc': 0.8938,
#   'blue': 0.5713,
#   'iteration': 1700},
#  {'epoch': 18,
#   'domain_acc': 0.9964,
#   'transfer_acc': 0.9083,
#   'blue': 0.5518,
#   'iteration': 1800},
#  {'epoch': 18,
#   'domain_acc': 0.9944,
#   'transfer_acc': 0.8991,
#   'blue': 0.5695,
#   'iteration': 1900},
#  {'epoch': 18,
#   'domain_acc': 0.9937,
#   'transfer_acc': 0.8682,
#   'blue': 0.6019,
#   'iteration': 2000},
#  {'epoch': 18,
#   'domain_acc': 0.9941,
#   'transfer_acc': 0.8996,
#   'blue': 0.5563,
#   'iteration': 2100},
#  {'epoch': 18,
#   'domain_acc': 0.9937,
#   'transfer_acc': 0.8949,
#   'blue': 0.5712,
#   'iteration': 2200},
#  {'epoch': 18,
#   'domain_acc': 0.994,
#   'transfer_acc': 0.8899,
#   'blue': 0.5764,
#   'iteration': 2300},
#  {'epoch': 18,
#   'domain_acc': 0.9932,
#   'transfer_acc': 0.8714,
#   'blue': 0.593,
#   'iteration': 2400},
#  {'epoch': 18,
#   'domain_acc': 0.9946,
#   'transfer_acc': 0.9025,
#   'blue': 0.5752,
#   'iteration': 2500},
#  {'epoch': 18,
#   'domain_acc': 0.9936,
#   'transfer_acc': 0.9026,
#   'blue': 0.566,
#   'iteration': 2600},
#  {'epoch': 18,
#   'domain_acc': 0.9946,
#   'transfer_acc': 0.9019,
#   'blue': 0.5686,
#   'iteration': 2700},
#  {'epoch': 18,
#   'domain_acc': 0.9956,
#   'transfer_acc': 0.9024,
#   'blue': 0.5695,
#   'iteration': 2800},
#  {'epoch': 18,
#   'domain_acc': 0.9941,
#   'transfer_acc': 0.9004,
#   'blue': 0.563,
#   'iteration': 2900},
#  {'epoch': 19,
#   'domain_acc': 0.9947,
#   'transfer_acc': 0.8988,
#   'blue': 0.5627,
#   'iteration': 100},
#  {'epoch': 19,
#   'domain_acc': 0.994,
#   'transfer_acc': 0.8994,
#   'blue': 0.5648,
#   'iteration': 200},
#  {'epoch': 19,
#   'domain_acc': 0.9948,
#   'transfer_acc': 0.8868,
#   'blue': 0.5706,
#   'iteration': 300},
#  {'epoch': 19,
#   'domain_acc': 0.994,
#   'transfer_acc': 0.9041,
#   'blue': 0.5624,
#   'iteration': 400},
#  {'epoch': 19,
#   'domain_acc': 0.9947,
#   'transfer_acc': 0.9113,
#   'blue': 0.5513,
#   'iteration': 500},
#  {'epoch': 19,
#   'domain_acc': 0.994,
#   'transfer_acc': 0.8878,
#   'blue': 0.5824,
#   'iteration': 600},
#  {'epoch': 19,
#   'domain_acc': 0.9939,
#   'transfer_acc': 0.9035,
#   'blue': 0.571,
#   'iteration': 700},
#  {'epoch': 19,
#   'domain_acc': 0.9953,
#   'transfer_acc': 0.8956,
#   'blue': 0.5686,
#   'iteration': 800},
#  {'epoch': 19,
#   'domain_acc': 0.9936,
#   'transfer_acc': 0.8837,
#   'blue': 0.586,
#   'iteration': 900},
#  {'epoch': 19,
#   'domain_acc': 0.9953,
#   'transfer_acc': 0.9028,
#   'blue': 0.5595,
#   'iteration': 1000},
#  {'epoch': 19,
#   'domain_acc': 0.9957,
#   'transfer_acc': 0.8919,
#   'blue': 0.5615,
#   'iteration': 1100},
#  {'epoch': 19,
#   'domain_acc': 0.9948,
#   'transfer_acc': 0.9045,
#   'blue': 0.5733,
#   'iteration': 1200},
#  {'epoch': 19,
#   'domain_acc': 0.9946,
#   'transfer_acc': 0.9181,
#   'blue': 0.5471,
#   'iteration': 1300},
#  {'epoch': 19,
#   'domain_acc': 0.9958,
#   'transfer_acc': 0.8913,
#   'blue': 0.5579,
#   'iteration': 1400},
#  {'epoch': 19,
#   'domain_acc': 0.9953,
#   'transfer_acc': 0.8928,
#   'blue': 0.5577,
#   'iteration': 1500},
#  {'epoch': 19,
#   'domain_acc': 0.9955,
#   'transfer_acc': 0.9105,
#   'blue': 0.543,
#   'iteration': 1600},
#  {'epoch': 19,
#   'domain_acc': 0.9948,
#   'transfer_acc': 0.8942,
#   'blue': 0.55,
#   'iteration': 1700},
#  {'epoch': 19,
#   'domain_acc': 0.995,
#   'transfer_acc': 0.9023,
#   'blue': 0.5412,
#   'iteration': 1800},
#  {'epoch': 19,
#   'domain_acc': 0.994,
#   'transfer_acc': 0.9113,
#   'blue': 0.5468,
#   'iteration': 1900},
#  {'epoch': 19,
#   'domain_acc': 0.995,
#   'transfer_acc': 0.9031,
#   'blue': 0.5512,
#   'iteration': 2000},
#  {'epoch': 19,
#   'domain_acc': 0.9939,
#   'transfer_acc': 0.9215,
#   'blue': 0.5329,
#   'iteration': 2100},
#  {'epoch': 19,
#   'domain_acc': 0.9935,
#   'transfer_acc': 0.9042,
#   'blue': 0.5627,
#   'iteration': 2200},
#  {'epoch': 19,
#   'domain_acc': 0.9939,
#   'transfer_acc': 0.9128,
#   'blue': 0.5502,
#   'iteration': 2300},
#  {'epoch': 19,
#   'domain_acc': 0.9934,
#   'transfer_acc': 0.903,
#   'blue': 0.5514,
#   'iteration': 2400},
#  {'epoch': 19,
#   'domain_acc': 0.9921,
#   'transfer_acc': 0.9018,
#   'blue': 0.5613,
#   'iteration': 2500},
#  {'epoch': 19,
#   'domain_acc': 0.9925,
#   'transfer_acc': 0.8902,
#   'blue': 0.5663,
#   'iteration': 2600},
#  {'epoch': 19,
#   'domain_acc': 0.9941,
#   'transfer_acc': 0.8892,
#   'blue': 0.5599,
#   'iteration': 2700},
#  {'epoch': 19,
#   'domain_acc': 0.9944,
#   'transfer_acc': 0.8972,
#   'blue': 0.5578,
#   'iteration': 2800},
#  {'epoch': 20,
#   'domain_acc': 0.9942,
#   'transfer_acc': 0.9051,
#   'blue': 0.5547,
#   'iteration': 100},
#  {'epoch': 20,
#   'domain_acc': 0.9928,
#   'transfer_acc': 0.9126,
#   'blue': 0.5495,
#   'iteration': 200},
#  {'epoch': 20,
#   'domain_acc': 0.9923,
#   'transfer_acc': 0.905,
#   'blue': 0.5448,
#   'iteration': 300},
#  {'epoch': 20,
#   'domain_acc': 0.9932,
#   'transfer_acc': 0.9186,
#   'blue': 0.5133,
#   'iteration': 400},
#  {'epoch': 20,
#   'domain_acc': 0.9944,
#   'transfer_acc': 0.9171,
#   'blue': 0.5411,
#   'iteration': 500},
#  {'epoch': 20,
#   'domain_acc': 0.9953,
#   'transfer_acc': 0.9073,
#   'blue': 0.54,
#   'iteration': 600},
#  {'epoch': 20,
#   'domain_acc': 0.9947,
#   'transfer_acc': 0.898,
#   'blue': 0.5611,
#   'iteration': 700},
#  {'epoch': 20,
#   'domain_acc': 0.9941,
#   'transfer_acc': 0.9036,
#   'blue': 0.5607,
#   'iteration': 800},
#  {'epoch': 20,
#   'domain_acc': 0.9926,
#   'transfer_acc': 0.9036,
#   'blue': 0.5634,
#   'iteration': 900},
#  {'epoch': 20,
#   'domain_acc': 0.9946,
#   'transfer_acc': 0.9057,
#   'blue': 0.5666,
#   'iteration': 1000},
#  {'epoch': 20,
#   'domain_acc': 0.9955,
#   'transfer_acc': 0.9149,
#   'blue': 0.533,
#   'iteration': 1100},
#  {'epoch': 20,
#   'domain_acc': 0.9936,
#   'transfer_acc': 0.8955,
#   'blue': 0.5643,
#   'iteration': 1200},
#  {'epoch': 20,
#   'domain_acc': 0.9937,
#   'transfer_acc': 0.8933,
#   'blue': 0.5754,
#   'iteration': 1300},
#  {'epoch': 20,
#   'domain_acc': 0.9928,
#   'transfer_acc': 0.8943,
#   'blue': 0.5659,
#   'iteration': 1400},
#  {'epoch': 20,
#   'domain_acc': 0.9931,
#   'transfer_acc': 0.9024,
#   'blue': 0.5617,
#   'iteration': 1500},
#  {'epoch': 20,
#   'domain_acc': 0.9937,
#   'transfer_acc': 0.8842,
#   'blue': 0.5897,
#   'iteration': 1600},
#  {'epoch': 20,
#   'domain_acc': 0.9941,
#   'transfer_acc': 0.9133,
#   'blue': 0.5446,
#   'iteration': 1700},
#  {'epoch': 20,
#   'domain_acc': 0.9952,
#   'transfer_acc': 0.9013,
#   'blue': 0.5602,
#   'iteration': 1800},
#  {'epoch': 20,
#   'domain_acc': 0.9946,
#   'transfer_acc': 0.8928,
#   'blue': 0.568,
#   'iteration': 1900},
#  {'epoch': 20,
#   'domain_acc': 0.9953,
#   'transfer_acc': 0.9078,
#   'blue': 0.5375,
#   'iteration': 2000},
#  {'epoch': 20,
#   'domain_acc': 0.9931,
#   'transfer_acc': 0.9106,
#   'blue': 0.5545,
#   'iteration': 2100},
#  {'epoch': 20,
#   'domain_acc': 0.9951,
#   'transfer_acc': 0.9062,
#   'blue': 0.5432,
#   'iteration': 2200},
#  {'epoch': 20,
#   'domain_acc': 0.9945,
#   'transfer_acc': 0.9039,
#   'blue': 0.5532,
#   'iteration': 2300},
#  {'epoch': 20,
#   'domain_acc': 0.9944,
#   'transfer_acc': 0.9144,
#   'blue': 0.5452,
#   'iteration': 2400},
#  {'epoch': 20,
#   'domain_acc': 0.9937,
#   'transfer_acc': 0.9158,
#   'blue': 0.5523,
#   'iteration': 2500},
#  {'epoch': 20,
#   'domain_acc': 0.9956,
#   'transfer_acc': 0.9061,
#   'blue': 0.5451,
#   'iteration': 2600},
#  {'epoch': 20,
#   'domain_acc': 0.9946,
#   'transfer_acc': 0.9102,
#   'blue': 0.5319,
#   'iteration': 2700},
#  {'epoch': 20,
#   'domain_acc': 0.9955,
#   'transfer_acc': 0.9109,
#   'blue': 0.5325,
#   'iteration': 2800},
#  {'epoch': 20,
#   'domain_acc': 0.9942,
#   'transfer_acc': 0.9094,
#   'blue': 0.5414,
#   'iteration': 2900}]

# %%
## Change log 2 pickle
for idx, rho in enumerate([1,5,10,25,100]):
    if idx != 0 :
        log_path = log_path.replace(str(previous_rho),str(rho))
    log_files = os.listdir(log_path)
    log_files = [i for i in log_files if i[-3:] == 'log']
    log_files.sort()
    log_file_path = os.path.join(log_path,log_files[-1])
    log2pickle(log_file_path,rho)
    previous_rho = rho
# Out:
# file path ../logs/rho1/DASTC__2020-06-30-08-07.log
# temp {'epoch': 1, 'domain_acc': 1.0, 'transfer_acc': 0.4996, 'blue': 0.0366, 'iteration': 100}
# file path ../logs/rho5/DASTC__2020-06-29-19-29.log
# temp {'epoch': 1, 'domain_acc': 1.0, 'transfer_acc': 0.5, 'blue': 0.0152, 'iteration': 100}
# file path ../logs/rho10/DASTC__2020-06-29-23-17.log
# temp {'epoch': 1, 'domain_acc': 1.0, 'transfer_acc': 0.5005, 'blue': 0.0007, 'iteration': 100}
# file path ../logs/rho25/DASTC__2020-06-30-21-24.log
# temp {'epoch': 1, 'domain_acc': 1.0, 'transfer_acc': 0.5, 'blue': 0.0118, 'iteration': 100}
# file path ../logs/rho100/DASTC__2020-07-01-01-18.log
# temp {'epoch': 1, 'domain_acc': 0.9847, 'transfer_acc': 0.5163, 'blue': 0.0199, 'iteration': 100}

# %%
import pickle
import matplotlib.pyplot as plt
import os

os.makedirs('vis', exist_ok = True)
os.makedirs('transfer_list', exist_ok = True)

rho = 1


# load losses
#with open('logs/' + 'rho' + str(rho) + '.pickle', 'rb') as f:
#	data = pickle.load(f)
data=pre_list

iter_list = [float(item['iteration']) for item in data][:-1]
domain_list = [float(item['domain_acc']) for item in data][:-1]
transfer_list = [float(item['transfer_acc']) for item in data][:-1]
bleu_list = [float(item['blue']) for item in data][:-1]

plt.plot(iter_list, domain_list)
plt.xlabel('Iteration')
plt.ylabel('Accuracy')
plt.title('Domain Accuracy')
plt.savefig('vis/pretrain_epoch_'+str(rho)+'_domain_acc' +'.png')
plt.close()

plt.plot(iter_list, transfer_list)
plt.xlabel('Iteration')
plt.ylabel('Accuracy')
plt.title('Transfer Accuracy')
plt.savefig('vis/pretrain_epoch_'+str(rho)+'_transfer_acc' +'.png')
plt.close()

plt.plot(iter_list, bleu_list)
plt.xlabel('Iteration')
plt.ylabel('Score')
plt.title('Bleu Score')
plt.savefig('vis/pretrain_epoch_'+str(rho)+'_bleu_score' +'.png')
plt.close()

# %%
recon_dict = {}
transfer_dict = {}

sample_sentences=[
	'but i can not help it that i can not take my eyes off of you',
	'and I am a man of expanding so why should i stand in her way',
	'and i swear by the moon and the stars in the sky ill be there',
	'baby I am baby I am hurt and i do not want to play anymore',
	'then I am willing to wait for it wait for it wait for it',
	'every inch of your skin is a holy gray I have got to find',
	'i never thought that you would be the one to hold my heart',
	'if she changes her mind this is the first place she will go',
	'oh her eyes her eyes make the stars look like they are not shinin']

total_dict = {}
for i in range(1,21):
	original_result, reconstruction_result, transfer_result =[], [], []  
	select_epoch = i
	# load sample sentences
	with open('logs/'+ str(pretrain_epoch) + '/' + 'domain_adapt/target/epoch'+ str(select_epoch) + '_reconstruction.txt', 'r') as f1:
		reconstruction = f1.readlines()
	with open('logs/'+ str(pretrain_epoch) + '/' + 'domain_adapt/target/epoch'+ str(select_epoch) + '_transfer.txt', 'r') as f2:
		transfer = f2.readlines()
	for recon in reconstruction:
		if recon.split('\t')[0] in sample_sentences:
			original_result.append(recon.split('\t')[0]) 
			reconstruction_result.append(recon.split('\t')[1]) 

	for trans in transfer:
		if trans.split('\t')[0] in sample_sentences:
			transfer_result.append(trans.split('\t')[1]) 

	total_dict[i] = {'original': original_result, 'recon': reconstruction_result, 'transfer': transfer_result}
	

with open('transfer_list/sample_result_' + str(pretrain_epoch) + '.pickle', 'wb') as result:
	pickle.dump(total_dict, result)
# Out:
# {'epoch': 1,
#  'iteration': 100,
#  'domain_acc': 0.7770061728395061,
#  'transfer_acc': 0.48148148148148145,
#  'blue': 0.04684147540877836}
